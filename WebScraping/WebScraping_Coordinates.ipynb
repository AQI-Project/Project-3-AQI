# %%
# Import dependencies
import requests
import time
from config import api_key
from bs4 import BeautifulSoup
from splinter import Browser
import pandas as pd
from pprint import pprint

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser("chrome", **executable_path, headless=False)

# %%
url = "https://www.latlong.net/latest-places.html"
browser.visit(url)

# %%
tables = pd.read_html(url)
tables
# Out:
# [                                           Place Name   Latitude   Longitude
#  0                       Kona Skate Park, Florida, USA  30.323277  -81.564995
#  1     Black Pearl Skate and Surf Park, Cayman Islands  19.282921  -81.345596
#  2             Breiner Company Incorporated, Avon, USA  39.758938  -86.388336
#  3             Howells Carpet Cleaning, Milwaukie, USA  45.454582 -122.585197
#  4            Burgers N' Fries Forever, Ottawa, Canada  45.414356  -75.695282
#  ..                                                ...        ...         ...
#  95                 Shopping City Süd, Vienna, Austria  48.108334   16.316944
#  96                   Tysons Corner Center, VA, the US  38.917130  -77.222237
#  97  Bluewater Shopping and Leisure Destination, Ke...  51.439640    0.271239
#  98                    Puerto Venecia, Zaragoza, Spain  41.608810   -0.888799
#  99            The Trafford Centre, Manchester, the UK  53.468399   -2.348900
#
#  [100 rows x 3 columns]]

# %%
type(tables)
# Out:
# list

# %%
df = tables[0]
df.columns = ["Place Name","Latitude","Longitude"]
df.head()
# Out:
#                                         Place Name   Latitude   Longitude
# 0                    Kona Skate Park, Florida, USA  30.323277  -81.564995
# 1  Black Pearl Skate and Surf Park, Cayman Islands  19.282921  -81.345596
# 2          Breiner Company Incorporated, Avon, USA  39.758938  -86.388336
# 3          Howells Carpet Cleaning, Milwaukie, USA  45.454582 -122.585197
# 4         Burgers N' Fries Forever, Ottawa, Canada  45.414356  -75.695282

# %%
lat = df["Latitude"]
lat
# Out:
# 0     30.323277
# 1     19.282921
# 2     39.758938
# 3     45.454582
# 4     45.414356
#         ...
# 95    48.108334
# 96    38.917130
# 97    51.439640
# 98    41.608810
# 99    53.468399
# Name: Latitude, Length: 100, dtype: float64

# %%
lon = df["Longitude"]
lon
# Out:
# 0     -81.564995
# 1     -81.345596
# 2     -86.388336
# 3    -122.585197
# 4     -75.695282
#          ...
# 95     16.316944
# 96    -77.222237
# 97      0.271239
# 98     -0.888799
# 99     -2.348900
# Name: Longitude, Length: 100, dtype: float64

# %%
saving_to_list = []
for x in lat:
    for y in lon:
        lat_lng = f'https://api.airvisual.com/v2/nearest_city?lat={round(x,2)}&lon={round(y,2)}&key='+ api_key
        #time.sleep(12)# reach 'https://www.iqair.com/air-pollution-data-api/plans'
        lat_lng_response = requests.get(lat_lng).json()
        saving_to_list.append(lat_lng_response)
        pprint(lat_lng_response)
# Out:
# {'data': {'city': 'Jacksonville',
#           'country': 'USA',
#           'current': {'pollution': {'aqicn': 8,
#                                     'aqius': 17,
#                                     'maincn': 'p1',
#                                     'mainus': 'p2',
#                                     'ts': '2020-06-11T00:00:00.000Z'},
#                       'weather': {'hu': 94,
#                                   'ic': '04n',
#                                   'pr': 1017,
#                                   'tp': 25,
#                                   'ts': '2020-06-11T01:00:00.000Z',
#                                   'wd': 160,
#                                   'ws': 3.6}},
#           'location': {'coordinates': [-81.5869, 30.4758], 'type': 'Point'},
#           'state': 'Florida'},
#  'status': 'success'}
# {'data': {'city': 'Jacksonville',
#           'country': 'USA',
#           'current': {'pollution': {'aqicn': 8,
#                                     'aqius': 17,
#                                     'maincn': 'p1',
#                                     'mainus': 'p2',
#                                     'ts': '2020-06-11T00:00:00.000Z'},
#                       'weather': {'hu': 94,
#                                   'ic': '04n',
#                                   'pr': 1017,
#                                   'tp': 25,
#                                   'ts': '2020-06-11T01:00:00.000Z',
#                                   'wd': 160,
#                                   'ws': 3.6}},
#           'location': {'coordinates': [-81.5869, 30.4758], 'type': 'Point'},
#           'state': 'Florida'},
#  'status': 'success'}
# {'data': {'city': 'Fort Walton Beach',
#           'country': 'USA',
#           'current': {'pollution': {'aqicn': 18,
#                                     'aqius': 50,
#                                     'maincn': 'p1',
#                                     'mainus': 'p2',
#                                     'ts': '2020-06-10T23:00:00.000Z'},
#                       'weather': {'hu': 83,
#                                   'ic': '04n',
#                                   'pr': 1015,
#                                   'tp': 27,
#                                   'ts': '2020-06-11T01:00:00.000Z',
#                                   'wd': 210,
#                                   'ws': 4.1}},
#           'location': {'coordinates': [-86.6669, 30.4244], 'type': 'Point'},
#           'state': 'Florida'},
#  'status': 'success'}
# {'data': {'city': 'Summerland',
#           'country': 'USA',
#           'current': {'pollution': {'aqicn': 2,
#                                     'aqius': 7,
#                                     'maincn': 'p2',
#                                     'mainus': 'p2',
#                                     'ts': '2020-06-11T01:00:00.000Z'},
#                       'weather': {'hu': 47,
#                                   'ic': '01d',
#                                   'pr': 1013,
#                                   'tp': 27,
#                                   'ts': '2020-06-11T01:00:00.000Z',
#                                   'wd': 200,
#                                   'ws': 1.5}},
#           'location': {'coordinates': [-119.726274, 33.996982],
#                        'type': 'Point'},
#           'state': 'California'},
#  'status': 'success'}
# {'data': {'city': 'Southport',
#           'country': 'USA',
#           'current': {'pollution': {'aqicn': 4,
#                                     'aqius': 13,
#                                     'maincn': 'p2',
#                                     'mainus': 'p2',
#                                     'ts': '2020-06-11T01:00:00.000Z'},
#                       'weather': {'hu': 78,
#                                   'ic': '04n',
#                                   'pr': 1019,
#                                   'tp': 25,
#                                   'ts': '2020-06-11T01:00:00.000Z',
#                                   'wd': 180,
#                                   'ws': 4.1}},
#           'location': {'coordinates': [-78.019167, 33.942222], 'type': 'Point'},
#           'state': 'North Carolina'},
#  'status': 'success'}
# {'data': {'city': 'Bandar Ganaveh',
#           'country': 'Iran',
#           'current': {'pollution': {'aqicn': 101,
#                                     'aqius': 117,
#                                     'maincn': 'p1',
#                                     'mainus': 'p2',
#                                     'ts': '2020-06-11T00:00:00.000Z'},
#                       'weather': {'hu': 39,
#                                   'ic': '01n',
#                                   'pr': 1002,
#                                   'tp': 30,
#                                   'ts': '2020-06-11T01:00:00.000Z',
#                                   'wd': 262,
#                                   'ws': 3.02}},
#           'location': {'coordinates': [50.508645, 29.5834822], 'type': 'Point'},
#           'state': 'Bushehr'},
#  'status': 'success'}
# {'data': {'city': 'Suining',
#           'country': 'China',
#           'current': {'pollution': {'aqicn': 49,
#                                     'aqius': 80,
#                                     'maincn': 'p1',
#                                     'mainus': 'p2',
#                                     'ts': '2020-06-11T00:00:00.000Z'},
#                       'weather': {'hu': 78,
#                                   'ic': '04d',
#                                   'pr': 1001,
#                                   'tp': 25,
#                                   'ts': '2020-06-11T01:00:00.000Z',
#                                   'wd': 14,
#                                   'ws': 2.07}},
#           'location': {'coordinates': [105.598125, 30.471724], 'type': 'Point'},
#           'state': 'Sichuan'},
#  'status': 'success'}
# {'data': {'city': 'Awendaw',
#           'country': 'USA',
#           'current': {'pollution': {'aqicn': 7,
#                                     'aqius': 20,
#                                     'maincn': 'p2',
#                                     'mainus': 'p2',
#                                     'ts': '2020-06-11T00:00:00.000Z'},
#                       'weather': {'hu': 88,
#                                   'ic': '04n',
#                                   'pr': 1017,
#                                   'tp': 26,
#                                   'ts': '2020-06-11T01:00:00.000Z',
#                                   'wd': 150,
#                                   'ws': 3.6}},
#           'location': {'coordinates': [-79.656998, 32.941002], 'type': 'Point'},
#           'state': 'South Carolina'},
#  'status': 'success'}
# {'data': {'city': "H'Attard",
#           'country': 'Malta',
#           'current': {'pollution': {'aqicn': 25,
#                                     'aqius': 33,
#                                     'maincn': 'o3',
#                                     'mainus': 'o3',
#                                     'ts': '2020-06-10T20:00:00.000Z'},
#                       'weather': {'hu': 68,
#                                   'ic': '01n',
#                                   'pr': 1015,
#                                   'tp': 19,
#                                   'ts': '2020-06-11T01:00:00.000Z',
#                                   'wd': 310,
#                                   'ws': 1.5}},
#           'location': {'coordinates': [14.434464000000002, 35.89001799948958],
#                        'type': 'Point'},
#           'state': 'Central'},
#  'status': 'success'}
# {'data': {'city': 'Rodalquilar',
#           'country': 'Spain',
#           'current': {'pollution': {'aqicn': 36,
#                                     'aqius': 47,
#                                     'maincn': 'o3',
#                                     'mainus': 'o3',
#                                     'ts': '2020-06-10T20:00:00.000Z'},
#                       'weather': {'hu': 82,
#                                   'ic': '04n',
#                                   'pr': 1013,
#                                   'tp': 18,
#                                   'ts': '2020-06-11T01:00:00.000Z',
#                                   'wd': 90,
#                                   'ws': 1.5}},
#           'location': {'coordinates': [-2.0381900000000006, 36.847449999484304],
#                        'type': 'Point'},
#           'state': 'Andalucia'},
#  'status': 'success'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'city': 'Minamisatsuma',
#           'country': 'Japan',
#           'current': {'pollution': {'aqicn': 9,
#                                     'aqius': 25,
#                                     'maincn': 'p2',
#                                     'mainus': 'p2',
#                                     'ts': '2020-06-10T23:00:00.000Z'},
#                       'weather': {'hu': 100,
#                                   'ic': '50d',
#                                   'pr': 1009,
#                                   'tp': 22,
#                                   'ts': '2020-06-11T01:00:00.000Z',
#                                   'wd': 200,
#                                   'ws': 5.7}},
#           'location': {'coordinates': [130.3234075, 31.4166121],
#                        'type': 'Point'},
#           'state': 'Kagoshima'},
#  'status': 'success'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'city': 'Anqing',
#           'country': 'China',
#           'current': {'pollution': {'aqicn': 40,
#                                     'aqius': 76,
#                                     'maincn': 'p1',
#                                     'mainus': 'p2',
#                                     'ts': '2020-06-11T00:00:00.000Z'},
#                       'weather': {'hu': 77,
#                                   'ic': '10d',
#                                   'pr': 1005,
#                                   'tp': 28,
#                                   'ts': '2020-06-11T01:00:00.000Z',
#                                   'wd': 174,
#                                   'ws': 0.77}},
#           'location': {'coordinates': [117.065564, 30.549717], 'type': 'Point'},
#           'state': 'Anhui'},
#  'status': 'success'}
# {'data': {'city': 'Wuhan',
#           'country': 'China',
#           'current': {'pollution': {'aqicn': 34,
#                                     'aqius': 75,
#                                     'maincn': 'p2',
#                                     'mainus': 'p2',
#                                     'ts': '2020-06-11T00:00:00.000Z'},
#                       'weather': {'hu': 83,
#                                   'ic': '50d',
#                                   'pr': 1005,
#                                   'tp': 27,
#                                   'ts': '2020-06-11T01:00:00.000Z',
#                                   'wd': 0,
#                                   'ws': 1}},
#           'location': {'coordinates': [114.4444954225, 30.6332050564],
#                        'type': 'Point'},
#           'state': 'Hubei'},
#  'status': 'success'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'city': 'Iz-Zejtun',
#           'country': 'Malta',
#           'current': {'pollution': {'aqicn': 24,
#                                     'aqius': 31,
#                                     'maincn': 'o3',
#                                     'mainus': 'o3',
#                                     'ts': '2020-06-10T19:00:00.000Z'},
#                       'weather': {'hu': 68,
#                                   'ic': '01n',
#                                   'pr': 1015,
#                                   'tp': 19,
#                                   'ts': '2020-06-11T01:00:00.000Z',
#                                   'wd': 310,
#                                   'ws': 1.5}},
#           'location': {'coordinates': [14.538986, 35.85229099948979],
#                        'type': 'Point'},
#           'state': 'South Eastern'},
#  'status': 'success'}
# {'data': {'city': 'Algiers',
#           'country': 'Algeria',
#           'current': {'pollution': {'aqicn': 23,
#                                     'aqius': 59,
#                                     'maincn': 'p2',
#                                     'mainus': 'p2',
#                                     'ts': '2020-06-11T00:00:00.000Z'},
#                       'weather': {'hu': 82,
#                                   'ic': '01n',
#                                   'pr': 1015,
#                                   'tp': 15,
#                                   'ts': '2020-06-11T01:00:00.000Z',
#                                   'wd': 110,
#                                   'ws': 2.1}},
#           'location': {'coordinates': [3.08746, 36.73225], 'type': 'Point'},
#           'state': 'Algiers'},
#  'status': 'success'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'city': 'Awendaw',
#           'country': 'USA',
#           'current': {'pollution': {'aqicn': 7,
#                                     'aqius': 20,
#                                     'maincn': 'p2',
#                                     'mainus': 'p2',
#                                     'ts': '2020-06-11T00:00:00.000Z'},
#                       'weather': {'hu': 88,
#                                   'ic': '04n',
#                                   'pr': 1017,
#                                   'tp': 26,
#                                   'ts': '2020-06-11T01:00:00.000Z',
#                                   'wd': 150,
#                                   'ws': 3.6}},
#           'location': {'coordinates': [-79.656998, 32.941002], 'type': 'Point'},
#           'state': 'South Carolina'},
#  'status': 'success'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'city': 'Gharb',
#           'country': 'Malta',
#           'current': {'pollution': {'aqicn': 1,
#                                     'aqius': 0,
#                                     'maincn': 'n2',
#                                     'mainus': 'n2',
#                                     'ts': '2020-06-10T20:00:00.000Z'},
#                       'weather': {'hu': 68,
#                                   'ic': '01n',
#                                   'pr': 1015,
#                                   'tp': 19,
#                                   'ts': '2020-06-11T01:00:00.000Z',
#                                   'wd': 310,
#                                   'ws': 1.5}},
#           'location': {'coordinates': [14.20889, 36.06], 'type': 'Point'},
#           'state': 'Gozo'},
#  'status': 'success'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'city': "H'Attard",
#           'country': 'Malta',
#           'current': {'pollution': {'aqicn': 25,
#                                     'aqius': 33,
#                                     'maincn': 'o3',
#                                     'mainus': 'o3',
#                                     'ts': '2020-06-10T20:00:00.000Z'},
#                       'weather': {'hu': 68,
#                                   'ic': '01n',
#                                   'pr': 1015,
#                                   'tp': 19,
#                                   'ts': '2020-06-11T01:00:00.000Z',
#                                   'wd': 310,
#                                   'ws': 1.5}},
#           'location': {'coordinates': [14.434464000000002, 35.89001799948958],
#                        'type': 'Point'},
#           'state': 'Central'},
#  'status': 'success'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'city': 'Ningbo',
#           'country': 'China',
#           'current': {'pollution': {'aqicn': 22,
#                                     'aqius': 45,
#                                     'maincn': 'p1',
#                                     'mainus': 'p2',
#                                     'ts': '2020-06-11T00:00:00.000Z'},
#                       'weather': {'hu': 88,
#                                   'ic': '03d',
#                                   'pr': 1005,
#                                   'tp': 28,
#                                   'ts': '2020-06-11T01:00:00.000Z',
#                                   'wd': 0,
#                                   'ws': 1}},
#           'location': {'coordinates': [121.5351415349, 29.8708987748],
#                        'type': 'Point'},
#           'state': 'Zhejiang'},
#  'status': 'success'}
# {'data': {'city': 'Summerland',
#           'country': 'USA',
#           'current': {'pollution': {'aqicn': 2,
#                                     'aqius': 7,
#                                     'maincn': 'p2',
#                                     'mainus': 'p2',
#                                     'ts': '2020-06-11T01:00:00.000Z'},
#                       'weather': {'hu': 47,
#                                   'ic': '01d',
#                                   'pr': 1013,
#                                   'tp': 27,
#                                   'ts': '2020-06-11T01:00:00.000Z',
#                                   'wd': 200,
#                                   'ws': 1.5}},
#           'location': {'coordinates': [-119.726274, 33.996982],
#                        'type': 'Point'},
#           'state': 'California'},
#  'status': 'success'}
# {'data': {'city': 'Algiers',
#           'country': 'Algeria',
#           'current': {'pollution': {'aqicn': 23,
#                                     'aqius': 59,
#                                     'maincn': 'p2',
#                                     'mainus': 'p2',
#                                     'ts': '2020-06-11T00:00:00.000Z'},
#                       'weather': {'hu': 82,
#                                   'ic': '01n',
#                                   'pr': 1015,
#                                   'tp': 15,
#                                   'ts': '2020-06-11T01:00:00.000Z',
#                                   'wd': 110,
#                                   'ws': 2.1}},
#           'location': {'coordinates': [3.08746, 36.73225], 'type': 'Point'},
#           'state': 'Algiers'},
#  'status': 'success'}
# {'data': {'city': 'Ganzizhou',
#           'country': 'China',
#           'current': {'pollution': {'aqicn': 21,
#                                     'aqius': 50,
#                                     'maincn': 'p1',
#                                     'mainus': 'p2',
#                                     'ts': '2020-06-11T00:00:00.000Z'},
#                       'weather': {'hu': 54,
#                                   'ic': '01d',
#                                   'pr': 1006,
#                                   'tp': 18,
#                                   'ts': '2020-06-11T01:00:00.000Z',
#                                   'wd': 84,
#                                   'ws': 0.44}},
#           'location': {'coordinates': [101.9533, 29.9972], 'type': 'Point'},
#           'state': 'Sichuan'},
#  'status': 'success'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'city': 'Nazaret',
#           'country': 'Spain',
#           'current': {'pollution': {'aqicn': 26,
#                                     'aqius': 33,
#                                     'maincn': 'o3',
#                                     'mainus': 'o3',
#                                     'ts': '2020-06-11T00:00:00.000Z'},
#                       'weather': {'hu': 64,
#                                   'ic': '03n',
#                                   'pr': 1020,
#                                   'tp': 21,
#                                   'ts': '2020-06-11T01:00:00.000Z',
#                                   'wd': 40,
#                                   'ws': 2.6}},
#           'location': {'coordinates': [-13.516497, 28.990249], 'type': 'Point'},
#           'state': 'Canarias'},
#  'status': 'success'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'city': 'Temara',
#           'country': 'Morocco',
#           'current': {'pollution': {'aqicn': 10,
#                                     'aqius': 28,
#                                     'maincn': 'p2',
#                                     'mainus': 'p2',
#                                     'ts': '2020-06-11T01:00:00.000Z'},
#                       'weather': {'hu': 64,
#                                   'ic': '02n',
#                                   'pr': 1018,
#                                   'tp': 19,
#                                   'ts': '2020-06-11T01:00:00.000Z',
#                                   'wd': 290,
#                                   'ws': 3.1}},
#           'location': {'coordinates': [-6.90656, 33.92866], 'type': 'Point'},
#           'state': 'Rabat-Sale-Kenitra'},
#  'status': 'success'}
# {'data': {'city': 'Moradabad',
#           'country': 'India',
#           'current': {'pollution': {'aqicn': 110,
#                                     'aqius': 165,
#                                     'maincn': 'p2',
#                                     'mainus': 'p2',
#                                     'ts': '2020-06-10T23:00:00.000Z'},
#                       'weather': {'hu': 28,
#                                   'ic': '01d',
#                                   'pr': 999,
#                                   'tp': 33,
#                                   'ts': '2020-06-11T01:00:00.000Z',
#                                   'wd': 93,
#                                   'ws': 2.93}},
#           'location': {'coordinates': [78.7213009, 28.825341], 'type': 'Point'},
#           'state': 'Uttar Pradesh'},
#  'status': 'success'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'city': 'Iz-Zejtun',
#           'country': 'Malta',
#           'current': {'pollution': {'aqicn': 24,
#                                     'aqius': 31,
#                                     'maincn': 'o3',
#                                     'mainus': 'o3',
#                                     'ts': '2020-06-10T19:00:00.000Z'},
#                       'weather': {'hu': 68,
#                                   'ic': '01n',
#                                   'pr': 1015,
#                                   'tp': 19,
#                                   'ts': '2020-06-11T01:00:00.000Z',
#                                   'wd': 310,
#                                   'ws': 1.5}},
#           'location': {'coordinates': [14.538986, 35.85229099948979],
#                        'type': 'Point'},
#           'state': 'South Eastern'},
#  'status': 'success'}
# {'data': {'city': 'Awendaw',
#           'country': 'USA',
#           'current': {'pollution': {'aqicn': 7,
#                                     'aqius': 20,
#                                     'maincn': 'p2',
#                                     'mainus': 'p2',
#                                     'ts': '2020-06-11T00:00:00.000Z'},
#                       'weather': {'hu': 88,
#                                   'ic': '04n',
#                                   'pr': 1017,
#                                   'tp': 26,
#                                   'ts': '2020-06-11T01:00:00.000Z',
#                                   'wd': 150,
#                                   'ws': 3.6}},
#           'location': {'coordinates': [-79.656998, 32.941002], 'type': 'Point'},
#           'state': 'South Carolina'},
#  'status': 'success'}
# {'data': {'city': 'Rodalquilar',
#           'country': 'Spain',
#           'current': {'pollution': {'aqicn': 37,
#                                     'aqius': 48,
#                                     'maincn': 'o3',
#                                     'mainus': 'o3',
#                                     'ts': '2020-06-10T21:00:00.000Z'},
#                       'weather': {'hu': 82,
#                                   'ic': '04n',
#                                   'pr': 1013,
#                                   'tp': 18,
#                                   'ts': '2020-06-11T01:00:00.000Z',
#                                   'wd': 90,
#                                   'ws': 1.5}},
#           'location': {'coordinates': [-2.0381900000000006, 36.847449999484304],
#                        'type': 'Point'},
#           'state': 'Andalucia'},
#  'status': 'success'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'city': 'Homestead',
#           'country': 'USA',
#           'current': {'pollution': {'aqicn': 0,
#                                     'aqius': 0,
#                                     'maincn': 'p2',
#                                     'mainus': 'p2',
#                                     'ts': '2020-06-10T23:00:00.000Z'},
#                       'weather': {'hu': 79,
#                                   'ic': '01n',
#                                   'pr': 1016,
#                                   'tp': 28,
#                                   'ts': '2020-06-11T01:00:00.000Z',
#                                   'wd': 90,
#                                   'ws': 1.5}},
#           'location': {'coordinates': [-80.4828, 25.4719], 'type': 'Point'},
#           'state': 'Florida'},
#  'status': 'success'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'city': 'Dakar',
#           'country': 'Senegal',
#           'current': {'pollution': {'aqicn': 25,
#                                     'aqius': 63,
#                                     'maincn': 'p2',
#                                     'mainus': 'p2',
#                                     'ts': '2020-06-11T00:00:00.000Z'},
#                       'weather': {'hu': 94,
#                                   'ic': '50n',
#                                   'pr': 1014,
#                                   'tp': 25,
#                                   'ts': '2020-06-11T01:00:00.000Z',
#                                   'wd': 280,
#                                   'ws': 2.1}},
#           'location': {'coordinates': [-17.44406, 14.6937], 'type': 'Point'},
#           'state': 'Dakar'},
#  'status': 'success'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'city': 'Nishizakicho',
#           'country': 'Japan',
#           'current': {'pollution': {'aqicn': 1,
#                                     'aqius': 0,
#                                     'maincn': 'n2',
#                                     'mainus': 'n2',
#                                     'ts': '2020-06-11T01:00:00.000Z'},
#                       'weather': {'hu': 89,
#                                   'ic': '04d',
#                                   'pr': 1011,
#                                   'tp': 28,
#                                   'ts': '2020-06-11T01:00:00.000Z',
#                                   'wd': 180,
#                                   'ws': 6.7}},
#           'location': {'coordinates': [127.6657053, 26.1460673],
#                        'type': 'Point'},
#           'state': 'Okinawa'},
#  'status': 'success'}
# {'data': {'message': 'no_nearest_city'}, 'status': 'fail'}
# {'data': {'message': 'no_nearest_city'}, 'status': 'fail'}
# {'data': {'message': 'no_nearest_city'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'city': 'Shanwei',
#           'country': 'China',
#           'current': {'pollution': {'aqicn': 9,
#                                     'aqius': 12,
#                                     'maincn': 'o3',
#                                     'mainus': 'o3',
#                                     'ts': '2020-06-11T00:00:00.000Z'},
#                       'weather': {'hu': 75,
#                                   'ic': '03d',
#                                   'pr': 1008,
#                                   'tp': 29,
#                                   'ts': '2020-06-11T01:00:00.000Z',
#                                   'wd': 228,
#                                   'ws': 2.42}},
#           'location': {'coordinates': [115.370147, 22.772239], 'type': 'Point'},
#           'state': 'Guangdong'},
#  'status': 'success'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'no_nearest_city'}, 'status': 'fail'}
# {'data': {'message': 'no_nearest_city'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'city': 'Tlalpan',
#           'country': 'Mexico',
#           'current': {'pollution': {'aqicn': 59,
#                                     'aqius': 58,
#                                     'maincn': 'p1',
#                                     'mainus': 'p1',
#                                     'ts': '2020-06-11T01:00:00.000Z'},
#                       'weather': {'hu': 33,
#                                   'ic': '04d',
#                                   'pr': 1027,
#                                   'tp': 23,
#                                   'ts': '2020-06-11T01:00:00.000Z',
#                                   'wd': 40,
#                                   'ws': 8.2}},
#           'location': {'coordinates': [-99.16206, 19.29513], 'type': 'Point'},
#           'state': 'Mexico City'},
#  'status': 'success'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'city': 'Homestead',
#           'country': 'USA',
#           'current': {'pollution': {'aqicn': 0,
#                                     'aqius': 0,
#                                     'maincn': 'p2',
#                                     'mainus': 'p2',
#                                     'ts': '2020-06-10T23:00:00.000Z'},
#                       'weather': {'hu': 79,
#                                   'ic': '01n',
#                                   'pr': 1016,
#                                   'tp': 28,
#                                   'ts': '2020-06-11T01:00:00.000Z',
#                                   'wd': 90,
#                                   'ws': 1.5}},
#           'location': {'coordinates': [-80.4828, 25.4719], 'type': 'Point'},
#           'state': 'Florida'},
#  'status': 'success'}
# {'data': {'city': 'Bamako',
#           'country': 'Mali',
#           'current': {'pollution': {'aqicn': 33,
#                                     'aqius': 74,
#                                     'maincn': 'p2',
#                                     'mainus': 'p2',
#                                     'ts': '2020-06-11T00:00:00.000Z'},
#                       'weather': {'hu': 74,
#                                   'ic': '01n',
#                                   'pr': 1016,
#                                   'tp': 27,
#                                   'ts': '2020-06-11T01:00:00.000Z',
#                                   'wd': 230,
#                                   'ws': 3.1}},
#           'location': {'coordinates': [-8, 12.65], 'type': 'Point'},
#           'state': 'Bamako'},
#  'status': 'success'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'city': 'Bamako',
#           'country': 'Mali',
#           'current': {'pollution': {'aqicn': 33,
#                                     'aqius': 74,
#                                     'maincn': 'p2',
#                                     'mainus': 'p2',
#                                     'ts': '2020-06-11T00:00:00.000Z'},
#                       'weather': {'hu': 74,
#                                   'ic': '01n',
#                                   'pr': 1016,
#                                   'tp': 27,
#                                   'ts': '2020-06-11T01:00:00.000Z',
#                                   'wd': 230,
#                                   'ws': 3.1}},
#           'location': {'coordinates': [-8, 12.65], 'type': 'Point'},
#           'state': 'Bamako'},
#  'status': 'success'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'no_nearest_city'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'city': 'Tamuning',
#           'country': 'USA',
#           'current': {'pollution': {'aqicn': 1,
#                                     'aqius': 2,
#                                     'maincn': 'p2',
#                                     'mainus': 'p2',
#                                     'ts': '2020-06-11T01:00:00.000Z'},
#                       'weather': {'hu': 62,
#                                   'ic': '04d',
#                                   'pr': 1013,
#                                   'tp': 30,
#                                   'ts': '2020-06-11T01:00:00.000Z',
#                                   'wd': 80,
#                                   'ws': 7.7}},
#           'location': {'coordinates': [144.780955, 13.481809], 'type': 'Point'},
#           'state': 'Tamuning'},
#  'status': 'success'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'no_nearest_city'}, 'status': 'fail'}
# {'data': {'city': 'Chandrapur',
#           'country': 'India',
#           'current': {'pollution': {'aqicn': 22,
#                                     'aqius': 24,
#                                     'maincn': 'p1',
#                                     'mainus': 'p2',
#                                     'ts': '2020-06-11T00:00:00.000Z'},
#                       'weather': {'hu': 57,
#                                   'ic': '04d',
#                                   'pr': 1000,
#                                   'tp': 30,
#                                   'ts': '2020-06-11T01:00:00.000Z',
#                                   'wd': 282,
#                                   'ws': 4.64}},
#           'location': {'coordinates': [79.3, 19.95], 'type': 'Point'},
#           'state': 'Maharashtra'},
#  'status': 'success'}
# {'data': {'message': 'no_nearest_city'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'city': 'Homestead',
#           'country': 'USA',
#           'current': {'pollution': {'aqicn': 0,
#                                     'aqius': 0,
#                                     'maincn': 'p2',
#                                     'mainus': 'p2',
#                                     'ts': '2020-06-10T23:00:00.000Z'},
#                       'weather': {'hu': 79,
#                                   'ic': '01n',
#                                   'pr': 1016,
#                                   'tp': 28,
#                                   'ts': '2020-06-11T01:00:00.000Z',
#                                   'wd': 90,
#                                   'ws': 1.5}},
#           'location': {'coordinates': [-80.4828, 25.4719], 'type': 'Point'},
#           'state': 'Florida'},
#  'status': 'success'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
# {'data': {'message': 'call_per_minute_limit_reached'}, 'status': 'fail'}
