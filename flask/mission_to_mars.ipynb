# %%
from bs4 import BeautifulSoup
import requests
from splinter import Browser
import pandas as pd
import time

# %%
# https://splinter.readthedocs.io/en/latest/drivers/chrome.html
# !which chromedriver
# Out:
# /usr/local/bin/chromedriver

# %%
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)
#UnboundLocalError: local variable 'e' referenced before assignment

# %%
def scrape_info(url):
    executable_path = {"executable_path": "/usr/local/bin/chromedriver"}
    browser = Browser('chrome', **executable_path, headless=False)
    browser.visit(url)
    time.sleep(2)
    html = browser.html
    soup =  BeautifulSoup(html,"html.parser")
    browser.quit()
    return soup

# %%
url = 'https://www.iqair.com/world-air-quality'

# %%
test_soup = scrape_info(url)
print(test_soup.prettify())
# Out:
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=5.0" name="viewport"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <title>
#    World Live Air Quality Map | AirVisual
#   </title>
#   <meta content="Compare real-time worldwide air quality levels with AirVisual's interactive air quality and pollution map. Learn from PM2.5 trends and our ranking of most polluted cities in the world." name="description"/>
#   <base href="/"/>
#   <meta content="app-id=1048912974" name="apple-itunes-app"/>
#   <link href="assets/favicons/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="assets/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="assets/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="assets/favicons/site.webmanifest" rel="manifest"/>
#   <link color="#d9272e" href="assets/favicons/safari-pinned-tab.svg" rel="mask-icon"/>
#   <link href="assets/favicons/favicon.ico?v=2" rel="shortcut icon"/>
#   <meta content="#ffffff" name="msapplication-TileColor"/>
#   <meta content="assets/favicons/browserconfig.xml" name="msapplication-config"/>
#   <meta content="#ffffff" name="theme-color"/>
#   <link href="styles.fd7fffd68208c42f468d.css" rel="stylesheet"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="@MyAirVisual" name="twitter:site"/>
#   <meta content="398656046993675" name="fb:app_id"/>
#   <link href="https://www.iqair.com/fr/world-air-quality" hreflang="fr" rel="alternate"/>
#   <link href="https://www.iqair.com/th/world-air-quality" hreflang="th" rel="alternate"/>
#   <link href="https://www.iqair.com/th-en/world-air-quality" hreflang="en-th" rel="alternate"/>
#   <link href="https://www.iqair.com/ko/world-air-quality" hreflang="ko" rel="alternate"/>
#   <link href="https://www.iqair.com/id/world-air-quality" hreflang="id" rel="alternate"/>
#   <link href="https://www.iqair.com/cn/world-air-quality" hreflang="zh-hans" rel="alternate"/>
#   <link href="https://www.iqair.com/cn-en/world-air-quality" hreflang="zh-en" rel="alternate"/>
#   <link href="https://www.iqair.com/tw/world-air-quality" hreflang="zh-tw" rel="alternate"/>
#   <link href="https://www.iqair.com/tw/world-air-quality" hreflang="zh-hant" rel="alternate"/>
#   <link href="https://www.iqair.com/ru/world-air-quality" hreflang="ru" rel="alternate"/>
#   <link href="https://www.iqair.com/vi/world-air-quality" hreflang="vi" rel="alternate"/>
#   <link href="https://www.iqair.com/ca/world-air-quality" hreflang="en-ca" rel="alternate"/>
#   <link href="https://www.iqair.com/us/world-air-quality" hreflang="en-us" rel="alternate"/>
#   <meta content="World Live Air Quality Map | AirVisual" property="og:title"/>
#   <meta content="https://www.iqair.com/world-air-quality" property="og:url"/>
#   <meta content="https://www.iqair.com/assets/favicons/iq-air-air-visual-logo.png" property="og:image"/>
#   <meta content="Compare real-time worldwide air quality levels with AirVisual's interactive air quality and pollution map. Learn from PM2.5 trends and our ranking of most polluted cities in the world." property="og:description"/>
#   <script async="" src="https://www.google-analytics.com/plugins/ua/ec.js" type="text/javascript">
#   </script>
#   <script async="" src="https://snip.bronto.com/v2/sites/eyJ0eXBlIjoic2l0ZWhhc2giLCJpZCI6ImMzZmRjYWNlZmRmZThlOTIyZjJiNzZmNjM3MGUwNmIzMTIxMzM0ZGRlMjNjMDMwMmE3ZGU5NmU2MGZlNGI4ZTkifQ==/assets/bundle.js">
#   </script>
#   <script async="" src="https://connect.facebook.net/signals/config/476595546403287?v=2.9.18&amp;r=stable">
#   </script>
#   <script async="" src="https://connect.facebook.net/signals/config/463163240733630?v=2.9.18&amp;r=stable">
#   </script>
#   <script async="" src="https://connect.facebook.net/en_US/fbevents.js">
#   </script>
#   <script async="" src="//www.googleadservices.com/pagead/conversion_async.js" type="text/javascript">
#   </script>
#   <script async="" src="//bat.bing.com/bat.js" type="text/javascript">
#   </script>
#   <script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript">
#   </script>
#   <script defer="" src="7-es2015.7e318379ca9f79b831ca.js">
#   </script>
#   <script defer="" src="11-es2015.5107814a2a7b27f1b9b1.js">
#   </script>
#   <script defer="" src="15-es2015.8f6cee821472aba5c523.js">
#   </script>
#   <script defer="" src="24-es2015.5b8b62379580dc0ac346.js">
#   </script>
#   <script defer="" src="109-es2015.8ae7f7e79ca5d3972069.js">
#   </script>
#   <script defer="" src="108-es2015.fb685c38b7ce867965d5.js">
#   </script>
#   <script defer="" src="4-es2015.d04bc3bef235b03088e6.js">
#   </script>
#   <script defer="" src="1-es2015.cb8cf1f97c84b44b9bb2.js">
#   </script>
#   <script defer="" src="3-es2015.049b30a123c3b6695c51.js">
#   </script>
#   <script defer="" src="2-es2015.a1ee05cf071e19a4fd48.js">
#   </script>
#   <script defer="" src="10-es2015.7e8de915f9f0f792da25.js">
#   </script>
#   <script defer="" src="14-es2015.b54d15c80f47fd2cc79c.js">
#   </script>
#   <script defer="" src="21-es2015.d0882cc2eb8de57ca526.js">
#   </script>
#   <script defer="" src="common-es2015.158924d548544c27ad12.js">
#   </script>
#   <script defer="" src="55-es2015.e9fce52627cae400c76e.js">
#   </script>
#   <script defer="" src="8-es2015.d424225de7c85eb40839.js">
#   </script>
#   <script defer="" src="12-es2015.46a07f7631d6d1b9f172.js">
#   </script>
#   <script defer="" src="43-es2015.183d9b0f7f7f57de3de8.js">
#   </script>
#   <style>
#    .mat-drawer-container[_ngcontent-airvisual-web-c0]{background-color:#fff}.mat-drawer-container[_ngcontent-airvisual-web-c0]    .mat-drawer-content{display:contents}
#   </style>
#   <style>
#    .site-cookie[_ngcontent-airvisual-web-c1]{position:relative;padding-right:72px;display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-ms-flex-pack:justify;justify-content:space-between;-webkit-box-align:center;-ms-flex-align:center;align-items:center}.site-cookie-container[_ngcontent-airvisual-web-c1]{position:fixed;bottom:0;left:0;width:100%;background:#2b353f;padding:24px 0;z-index:1001}.site-cookie[_ngcontent-airvisual-web-c1]   .description[_ngcontent-airvisual-web-c1]{font-size:16px;line-height:1.5;-webkit-box-flex:1;-ms-flex:1 1 auto;flex:1 1 auto;padding-right:80px}.site-cookie[_ngcontent-airvisual-web-c1]   .description[_ngcontent-airvisual-web-c1]   p[_ngcontent-airvisual-web-c1]{color:#fff!important}.site-cookie[_ngcontent-airvisual-web-c1]   .description[_ngcontent-airvisual-web-c1]   a[_ngcontent-airvisual-web-c1]{color:#60b3cf;font-weight:700}.site-cookie[_ngcontent-airvisual-web-c1]   .btnAccept[_ngcontent-airvisual-web-c1]{width:140px;height:36px;border-radius:2px;font-size:12px;background:#60b3cf;color:#fff;border:none;cursor:pointer}.site-cookie[_ngcontent-airvisual-web-c1]   .btnClose[_ngcontent-airvisual-web-c1]{background:0 0;border:none;position:absolute;top:50%;right:0;-webkit-transform:translateY(-50%);-ms-transform:translateY(-50%);transform:translateY(-50%);cursor:pointer}@media only screen and (max-width:599px){.site-cookie[_ngcontent-airvisual-web-c1]{padding-right:15px;-webkit-box-orient:vertical;-webkit-box-direction:normal;-ms-flex-direction:column;flex-direction:column;-webkit-box-align:start;-ms-flex-align:start;align-items:flex-start}.site-cookie[_ngcontent-airvisual-web-c1]   .description[_ngcontent-airvisual-web-c1]{padding-right:24px;margin-bottom:16px}.site-cookie[_ngcontent-airvisual-web-c1]   .btnClose[_ngcontent-airvisual-web-c1]{-webkit-transform:none;-ms-transform:none;transform:none;top:0;right:15px}}
#   </style>
#   <script charset="utf-8" src="assets/iqair/js/jquery-3.2.1.min.js" type="text/javascript">
#   </script>
#   <script charset="utf-8" src="assets/iqair/js/jquery.cookie.min.js" type="text/javascript">
#   </script>
#   <script charset="utf-8" src="assets/scripts/fb-pixel.js" type="text/javascript">
#   </script>
#   <style>
#   </style>
#   <style>
#    .tooltip[_ngcontent-airvisual-web-c3]{cursor:pointer}.banner-top-margin[_ngcontent-airvisual-web-c3]{margin-top:96px}.header-container[_ngcontent-airvisual-web-c3]{width:100%;position:fixed;z-index:1000;background:#fff}.dropdown-container[_ngcontent-airvisual-web-c3]{position:relative;border-bottom:1px solid rgba(0,0,0,.24)}.tooltip[_ngcontent-airvisual-web-c3]   .tooltiptext[_ngcontent-airvisual-web-c3]{visibility:hidden;width:120px;background-color:#000;color:#fff;text-align:center;border-radius:6px;padding:5px 0;position:absolute;z-index:1}.tooltip[_ngcontent-airvisual-web-c3]:hover   .tooltiptext[_ngcontent-airvisual-web-c3]{visibility:visible}.header-search[_ngcontent-airvisual-web-c3]{display:block;position:relative;margin-left:47px;max-width:448px}@media only screen and (min-width:1140px) and (max-width:1439px){.header-search[_ngcontent-airvisual-web-c3]{margin-left:16px;max-width:224px}}@media only screen and (min-width:960px) and (max-width:1139px){.header-search[_ngcontent-airvisual-web-c3]{margin-right:47px}}@media only screen and (max-width:959px){.header-search[_ngcontent-airvisual-web-c3]{display:none}}.nav-primary-container[_ngcontent-airvisual-web-c3]{display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-pack:end;-ms-flex-pack:end;justify-content:flex-end;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin-right:15px}.btn-link[_ngcontent-airvisual-web-c3]{font-size:16px;font-weight:400;color:#414141;border:0;outline:0;cursor:pointer;background-color:transparent}.btn-link[_ngcontent-airvisual-web-c3]:focus, .btn-link[_ngcontent-airvisual-web-c3]:hover{color:#456e98}.top-header[_ngcontent-airvisual-web-c3]{height:68px;color:#414141}.top-header-search[_ngcontent-airvisual-web-c3]{position:relative}.top-header-search[_ngcontent-airvisual-web-c3]   input[_ngcontent-airvisual-web-c3]{font:inherit;line-height:2.8!important;margin:0 0 0 30px;height:42px;width:calc(100% - 35px);padding:8px 15px;color:#49739a;-webkit-appearance:none;-moz-appearance:textfield;border-radius:4px;outline:0;-webkit-transition:.3s;transition:.3s all;background-color:#fff;border:1px solid #49739a;box-shadow:1px 1px 3px 0 rgba(0,0,0,.18)}.top-header-search[_ngcontent-airvisual-web-c3]   input[_ngcontent-airvisual-web-c3]::-webkit-input-placeholder{color:#49739a}.top-header-search[_ngcontent-airvisual-web-c3]   input[_ngcontent-airvisual-web-c3]::-moz-placeholder{color:#49739a}.top-header-search[_ngcontent-airvisual-web-c3]   input[_ngcontent-airvisual-web-c3]:-ms-input-placeholder{color:#49739a}.top-header-search[_ngcontent-airvisual-web-c3]   input[_ngcontent-airvisual-web-c3]::-ms-input-placeholder{color:#49739a}.top-header-search[_ngcontent-airvisual-web-c3]   input[_ngcontent-airvisual-web-c3]::placeholder{color:#49739a}.top-header-search.has-icon[_ngcontent-airvisual-web-c3]   .svg.airvisual-ic-search[_ngcontent-airvisual-web-c3]{width:24px;height:24px;position:absolute;right:10px;top:10px}.top-header[_ngcontent-airvisual-web-c3]   .has-dropdown[_ngcontent-airvisual-web-c3]{position:relative}.top-header[_ngcontent-airvisual-web-c3]   .has-dropdown[_ngcontent-airvisual-web-c3]   .selection-list[_ngcontent-airvisual-web-c3]{position:absolute;min-width:300px;-webkit-transform:translateY(20px);-ms-transform:translateY(20px);transform:translateY(20px);right:0;background:#fff;border-radius:8px 8px 0 0;box-shadow:0 10px 16px 0 rgba(0,0,0,.13),0 6px 20px 0 rgba(0,0,0,.08);z-index:-1;visibility:hidden;-webkit-transition:150ms ease-out;transition:all 150ms ease-out}.top-header[_ngcontent-airvisual-web-c3]   .has-dropdown[_ngcontent-airvisual-web-c3]   .selection-list.is-active[_ngcontent-airvisual-web-c3]{-webkit-transform:translateY(10px);-ms-transform:translateY(10px);transform:translateY(10px);visibility:visible;z-index:8}.top-header[_ngcontent-airvisual-web-c3]   .has-dropdown[_ngcontent-airvisual-web-c3]   .selection-list-title[_ngcontent-airvisual-web-c3]{padding-top:15px;padding-left:15px;margin:0}.header-rig ...
#   </style>
#   <style>
#    .mb12[_ngcontent-airvisual-web-c4]{margin-bottom:12px}.section-2[_ngcontent-airvisual-web-c4]{padding-bottom:25px}.footer[_ngcontent-airvisual-web-c4]{border-top:1px solid #e6e6e6}.footer[_ngcontent-airvisual-web-c4]   .container[_ngcontent-airvisual-web-c4]{padding:0}.footer-navigation[_ngcontent-airvisual-web-c4]{padding:85px 0 18px;border-bottom:1px solid #e6e6e6}.footer-navigation[_ngcontent-airvisual-web-c4]   .social-icon[_ngcontent-airvisual-web-c4]{margin-bottom:15px}.footer-navigation[_ngcontent-airvisual-web-c4]   .social-icon[_ngcontent-airvisual-web-c4]   a[_ngcontent-airvisual-web-c4]{text-decoration:none;color:#456e98;display:inline-block;width:24px;height:24px;margin-right:10px}.footer-navigation[_ngcontent-airvisual-web-c4]   .social-icon[_ngcontent-airvisual-web-c4]   a[_ngcontent-airvisual-web-c4]   img[_ngcontent-airvisual-web-c4]{height:16px;width:auto}.footer-navigation[_ngcontent-airvisual-web-c4]   h4[_ngcontent-airvisual-web-c4]{font-weight:700;line-height:1.75;color:#414141;font-size:18px}.footer-navigation[_ngcontent-airvisual-web-c4]   .list-items[_ngcontent-airvisual-web-c4]{padding-left:0}.footer-navigation[_ngcontent-airvisual-web-c4]   .list-items[_ngcontent-airvisual-web-c4]   a[_ngcontent-airvisual-web-c4]{display:block;text-decoration:none;line-height:1.86;color:#414141;font-size:16px}.footer-enterprise[_ngcontent-airvisual-web-c4]{padding:18px 0 20px;border-bottom:1px solid #e6e6e6}.footer-enterprise[_ngcontent-airvisual-web-c4]   h3.title[_ngcontent-airvisual-web-c4]{font-size:12px;color:#456e98;line-height:1.67}.footer-enterprise[_ngcontent-airvisual-web-c4]   a.link[_ngcontent-airvisual-web-c4]{font-size:14px;line-height:1.43;letter-spacing:normal;color:#456e98}.footer-bottom[_ngcontent-airvisual-web-c4]{padding-top:21px;padding-bottom:11px;font-size:12px;line-height:1.75;color:#49739a}.footer-bottom[_ngcontent-airvisual-web-c4]   img[_ngcontent-airvisual-web-c4]{margin-right:1rem;display:-webkit-inline-box;display:-ms-inline-flexbox;display:inline-flex;vertical-align:middle}.footer[_ngcontent-airvisual-web-c4]   .section-header[_ngcontent-airvisual-web-c4]{display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-ms-flex-pack:justify;justify-content:space-between;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin-bottom:26px;padding-top:6px}.footer[_ngcontent-airvisual-web-c4]   .section-header[_ngcontent-airvisual-web-c4]   img[_ngcontent-airvisual-web-c4]{visibility:hidden}.footer[_ngcontent-airvisual-web-c4]   .section-1[_ngcontent-airvisual-web-c4], .footer[_ngcontent-airvisual-web-c4]   .section-2[_ngcontent-airvisual-web-c4]{border:none;color:#414141}.footer[_ngcontent-airvisual-web-c4]   .connect-with-iqair[_ngcontent-airvisual-web-c4]   .section-header[_ngcontent-airvisual-web-c4]{font-size:18px;line-height:1.5}.footer[_ngcontent-airvisual-web-c4]   .connect-with-iqair[_ngcontent-airvisual-web-c4]   .__signUp[_ngcontent-airvisual-web-c4]   .mat-form-field-type-mat-input[_ngcontent-airvisual-web-c4]{width:100%}.footer[_ngcontent-airvisual-web-c4]   .connect-with-iqair[_ngcontent-airvisual-web-c4]   .__signUp[_ngcontent-airvisual-web-c4]   .btn-auth[_ngcontent-airvisual-web-c4]{font-size:12px;letter-spacing:1.2px;padding:0 30px;margin-top:16px;width:123px;height:48px;border-radius:2px;background-color:#49739a}.footer[_ngcontent-airvisual-web-c4]   .connect-with-iqair[_ngcontent-airvisual-web-c4]   .__signUp-sub-text[_ngcontent-airvisual-web-c4]{margin-top:-20px;margin-bottom:24px;line-height:1.33;color:#414141;font-size:12px}.footer[_ngcontent-airvisual-web-c4]   .connect-with-iqair[_ngcontent-airvisual-web-c4]   .__signUp-qrcode[_ngcontent-airvisual-web-c4]{width:72px;height:72px;margin-top:-8px}.footer[_ngcontent-airvisual-web-c4]   .connect-with-iqair[_ngcontent-airvisual-web-c4]   .__header[_ngcontent-airvisual-web-c4]{max-width:342px;max-height:108px;margin-bottom:32px}.footer[_ngcontent-airvisual-web-c4]   .connect-with-iqair[_ngco ...
#   </style>
#   <style type="text/css">
#    /*
#   @angular/flex-layout - workaround for possible browser quirk with mediaQuery listeners
#   see http://bit.ly/2sd4HMP
# */
# @media (min-width: 600px), (min-width: 960px), (min-width: 1140px), (min-width: 1440px), (min-width: 1440px) and (max-width: 5000px), (max-width: 1439px), (min-width: 1140px) and (max-width: 1439px), (max-width: 1139px), (min-width: 960px) and (max-width: 1139px), (max-width: 959px), (min-width: 600px) and (max-width: 959px), (max-width: 599px), (min-width: 0px) and (max-width: 599px), print {.fx-query-test{ }}
#   </style>
#   <style>
#    .search-form[_ngcontent-airvisual-web-c5]{background:#f6f6f6;border-radius:4px;padding:0 16px;height:48px}.search-form[_ngcontent-airvisual-web-c5]   .input[_ngcontent-airvisual-web-c5]   input[_ngcontent-airvisual-web-c5]{width:100%;color:#414141;background:0 0;border:none;padding:0 6px;height:48px;font-size:16px}.search-form[_ngcontent-airvisual-web-c5]   .input[_ngcontent-airvisual-web-c5]   input[_ngcontent-airvisual-web-c5]:focus{outline:0;box-shadow:none}.search-form[_ngcontent-airvisual-web-c5]   .input[_ngcontent-airvisual-web-c5]   input[_ngcontent-airvisual-web-c5]::-webkit-input-placeholder{color:rgba(0,0,0,.5);font-size:16px}.search-form[_ngcontent-airvisual-web-c5]   .input[_ngcontent-airvisual-web-c5]   input[_ngcontent-airvisual-web-c5]::-moz-placeholder{color:rgba(0,0,0,.5);font-size:16px}.search-form[_ngcontent-airvisual-web-c5]   .input[_ngcontent-airvisual-web-c5]   input[_ngcontent-airvisual-web-c5]:-ms-input-placeholder{color:rgba(0,0,0,.5);font-size:16px}.search-form[_ngcontent-airvisual-web-c5]   .input[_ngcontent-airvisual-web-c5]   input[_ngcontent-airvisual-web-c5]::-ms-input-placeholder{color:rgba(0,0,0,.5);font-size:16px}.search-form[_ngcontent-airvisual-web-c5]   .input[_ngcontent-airvisual-web-c5]   input[_ngcontent-airvisual-web-c5]::placeholder{color:rgba(0,0,0,.5);font-size:16px}.search-form[_ngcontent-airvisual-web-c5]   .input[_ngcontent-airvisual-web-c5]   input[_ngcontent-airvisual-web-c5]::-ms-clear{display:none}.search-form[_ngcontent-airvisual-web-c5]   .icon[_ngcontent-airvisual-web-c5]   img[_ngcontent-airvisual-web-c5]{width:24px;height:24px;opacity:.5}.search-form[_ngcontent-airvisual-web-c5]   .icon[_ngcontent-airvisual-web-c5]   img.ic-clear[_ngcontent-airvisual-web-c5]{cursor:pointer}.is-focused[_ngcontent-airvisual-web-c5]{-webkit-box-orient:horizontal!important;-webkit-box-direction:reverse!important;-ms-flex-direction:row-reverse!important;flex-direction:row-reverse!important;border:2px solid #ccd4e0}.overlay[_ngcontent-airvisual-web-c5]{position:fixed;width:100%;height:100%;top:69px;left:0;right:0;bottom:0;background-color:rgba(0,0,0,.16);cursor:pointer}
#   </style>
#   <style>
#    .header-navigation-item[_ngcontent-airvisual-web-c6]{display:inline-block;padding:0 10px}.header-navigation-item.active[_ngcontent-airvisual-web-c6]   .heading[_ngcontent-airvisual-web-c6], .header-navigation-item[_ngcontent-airvisual-web-c6]:active   .heading[_ngcontent-airvisual-web-c6], .header-navigation-item[_ngcontent-airvisual-web-c6]:hover   .heading[_ngcontent-airvisual-web-c6]{border-bottom:4px solid #4db1cf}.header-navigation-item.active[_ngcontent-airvisual-web-c6]   .nav-dropdown[_ngcontent-airvisual-web-c6], .header-navigation-item[_ngcontent-airvisual-web-c6]:active   .nav-dropdown[_ngcontent-airvisual-web-c6], .header-navigation-item[_ngcontent-airvisual-web-c6]:hover   .nav-dropdown[_ngcontent-airvisual-web-c6]{visibility:visible;-webkit-transform:translateY(0);-ms-transform:translateY(0);transform:translateY(0);-webkit-transition:325ms cubic-bezier(.4,0,.2,1);transition:all 325ms cubic-bezier(.4,0,.2,1)}.header-navigation-item.active[_ngcontent-airvisual-web-c6]   .nav-dropdown.hide[_ngcontent-airvisual-web-c6], .header-navigation-item[_ngcontent-airvisual-web-c6]:active   .nav-dropdown.hide[_ngcontent-airvisual-web-c6], .header-navigation-item[_ngcontent-airvisual-web-c6]:hover   .nav-dropdown.hide[_ngcontent-airvisual-web-c6]{visibility:hidden;-webkit-transform:translateY(10px);-ms-transform:translateY(10px);transform:translateY(10px);-webkit-transition:none;transition:none}.header-navigation-item[_ngcontent-airvisual-web-c6]   .heading[_ngcontent-airvisual-web-c6]{cursor:pointer;font-weight:500;display:block;border-bottom:4px solid #fff;display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-ms-flex-pack:center;justify-content:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:66px;padding-top:4px}.header-navigation-item[_ngcontent-airvisual-web-c6]   .heading.active[_ngcontent-airvisual-web-c6]{border-bottom:4px solid #4db1cf}.header-navigation-item[_ngcontent-airvisual-web-c6]   .nav-dropdown[_ngcontent-airvisual-web-c6]{position:absolute;top:100%;left:0;width:100%;-webkit-transform:translateY(10px);-ms-transform:translateY(10px);transform:translateY(10px);overflow-y:auto;padding:40px 0 60px;box-shadow:0 2px 4px 0 rgba(0,0,0,.24);visibility:hidden;background:#fff;z-index:1}.header-navigation-item[_ngcontent-airvisual-web-c6]   .nav-dropdown.nav-supports[_ngcontent-airvisual-web-c6]{height:284px!important;padding-top:32px}.header-navigation-item[_ngcontent-airvisual-web-c6]   .nav-dropdown.nav-supports[_ngcontent-airvisual-web-c6]   .container[_ngcontent-airvisual-web-c6]{-webkit-box-pack:center;-ms-flex-pack:center;justify-content:center}.header-navigation-item[_ngcontent-airvisual-web-c6]   .nav-dropdown.nav-supports[_ngcontent-airvisual-web-c6]   .support-item[_ngcontent-airvisual-web-c6]{width:342px;height:189px;overflow:hidden;position:relative;box-shadow:0 2px 12px 0 rgba(0,0,0,.12);margin:0 12px}.header-navigation-item[_ngcontent-airvisual-web-c6]   .nav-dropdown.nav-supports[_ngcontent-airvisual-web-c6]   .support-item[_ngcontent-airvisual-web-c6]:before{content:"";position:absolute;width:100%;height:100%;top:0;left:0;background:-webkit-gradient(linear,left bottom,left top,color-stop(15%,rgba(0,0,0,.2)),color-stop(50%,rgba(255,255,255,0)));background:linear-gradient(0deg,rgba(0,0,0,.2) 15%,rgba(255,255,255,0) 50%)}.header-navigation-item[_ngcontent-airvisual-web-c6]   .nav-dropdown.nav-supports[_ngcontent-airvisual-web-c6]   .support-item[_ngcontent-airvisual-web-c6]   img[_ngcontent-airvisual-web-c6]{width:100%;height:100%}.header-navigation-item[_ngcontent-airvisual-web-c6]   .nav-dropdown.nav-supports[_ngcontent-airvisual-web-c6]   .support-item[_ngcontent-airvisual-web-c6]   h5[_ngcontent-airvisual-web-c6]{position:absolute;bottom:16px;left:0;padding:0 16px;color:#fff;font-size:18px;font-weight:700;text-shadow:0 1px 3px #414141}.header-navigation-item[_ngcontent-airvisual-web-c6]   .nav-dropdown[_ngcontent-airvisual-web-c6]   .container[_ng ...
#   </style>
#   <style>
#    .size-medium[_ngcontent-airvisual-web-c7]{display:none!important}.item-label-image-description-waq[_ngcontent-airvisual-web-c7]{max-width:100%!important;line-height:1!important}.item-label-description-solutions[_ngcontent-airvisual-web-c7]{line-height:1!important}.app-img-container[_ngcontent-airvisual-web-c7]{display:-webkit-box;display:-ms-flexbox;display:flex;width:100%;padding-bottom:0;padding-right:15px;-webkit-box-pack:justify;-ms-flex-pack:justify;justify-content:space-between}.app-img-os[_ngcontent-airvisual-web-c7]{width:50%!important;height:35px!important;-o-object-fit:contain!important;object-fit:contain!important}.app-img-os-ios[_ngcontent-airvisual-web-c7]{margin-right:3px}.item-help-extra-us[_ngcontent-airvisual-web-c7]{display:-webkit-box;display:-ms-flexbox;display:flex;height:96px;margin-top:16px;cursor:pointer;width:100%;box-shadow:0 2px 12px 0 rgba(0,0,0,.12);padding:14px 16px;font-weight:700;text-align:center}.item-help-extra-us[_ngcontent-airvisual-web-c7]   .globe[_ngcontent-airvisual-web-c7]{margin:10px 10px 15px 9px}.item-help-extra-us[_ngcontent-airvisual-web-c7]   .globe[_ngcontent-airvisual-web-c7]   img[_ngcontent-airvisual-web-c7]{width:48px;height:48px}.item-help-extra-us-text-container[_ngcontent-airvisual-web-c7]{display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-orient:vertical;-webkit-box-direction:normal;-ms-flex-direction:column;flex-direction:column;-webkit-box-align:start;-ms-flex-align:start;align-items:flex-start;margin-left:5px}.item-help-extra-us-text[_ngcontent-airvisual-web-c7]{font-size:16px;line-height:2.25;font-weight:400;max-width:100%!important;text-align:center!important;margin-bottom:8px}.item-help-extra-us-text-sub[_ngcontent-airvisual-web-c7]{width:auto;font-size:16px;font-weight:400;line-height:1.5;color:#414141}#shopify-item-count[_ngcontent-airvisual-web-c7]{font-size:14px!important;background-color:#4fbe83!important;border-radius:50%;width:20px;height:20px;line-height:20px;text-align:center;color:#fff;float:right;visibility:hidden}.mat-drawer[_ngcontent-airvisual-web-c7]{z-index:1002}.btn-track[_ngcontent-airvisual-web-c7]{width:auto;text-transform:uppercase;margin-left:30px;margin-right:20px}.icon-gear[_ngcontent-airvisual-web-c7]   img[_ngcontent-airvisual-web-c7]{width:24px}.mb16[_ngcontent-airvisual-web-c7]{margin-bottom:16px}.ml10[_ngcontent-airvisual-web-c7]{margin-left:10px}.border-seperator[_ngcontent-airvisual-web-c7]{background:#e6e6e6;width:1px;margin-right:20px}.btn-myair[_ngcontent-airvisual-web-c7]{margin-right:20px}.avatar-container[_ngcontent-airvisual-web-c7]{cursor:pointer;position:relative}.header-right-more[_ngcontent-airvisual-web-c7]{display:none}.pc-size-container[_ngcontent-airvisual-web-c7]{height:40px}.avatar[_ngcontent-airvisual-web-c7]{width:42px;height:42px;border-radius:100%;-o-object-fit:cover;object-fit:cover}.btn-get-monitor[_ngcontent-airvisual-web-c7]{margin-left:30px;text-transform:uppercase}.nav-links[_ngcontent-airvisual-web-c7]{font-weight:500;color:#414141;margin:0 10px;cursor:pointer;font-size:16px}.header-right[_ngcontent-airvisual-web-c7]{border-left:1px solid #e6e6e6;padding-left:15px}.header-right-search-icon[_ngcontent-airvisual-web-c7]{cursor:pointer;display:none}@media only screen and (max-width:959px){.header-right-search-icon[_ngcontent-airvisual-web-c7]{display:block;width:24px;height:24px}}.header-right-links[_ngcontent-airvisual-web-c7]{font-size:16px}.header-right-dropdown[_ngcontent-airvisual-web-c7]{border-radius:5px;background-color:#fff;box-shadow:0 2px 4px 0 rgba(0,0,0,.2);width:200px;padding:25px 30px;position:absolute;right:0;visibility:hidden;-webkit-transform:translateY(20px);-ms-transform:translateY(20px);transform:translateY(20px);-webkit-transition:-webkit-transform 150ms ease-out;transition:-webkit-transform 150ms ease-out;transition:transform 150ms ease-out;transition:transform 150ms ease-out,-webkit-transform 150ms ease-out}.header-right-dropdown.active[_ngcontent-airvisual-web-c7]{-web ...
#   </style>
#   <style>
#    .search-container[_ngcontent-airvisual-web-c14]   .dropdown-container[_ngcontent-airvisual-web-c14]{position:absolute;top:100%;left:0;background:#fff;box-shadow:0 1px 4px 0 rgba(0,0,0,.2);border-radius:0 0 6px 6px;color:#414141;font-size:14px;z-index:999;margin-top:0;padding-bottom:16px;pointer-events:auto}.search-container[_ngcontent-airvisual-web-c14]   .dropdown-container.header-search-container[_ngcontent-airvisual-web-c14]{margin-top:11px}.search-container[_ngcontent-airvisual-web-c14]   .dropdown-container.isMobile[_ngcontent-airvisual-web-c14]{box-shadow:none;margin-top:0;padding-top:0}.search-container[_ngcontent-airvisual-web-c14]   .dropdown-container.bt70[_ngcontent-airvisual-web-c14]{bottom:70px;top:auto}.search-container[_ngcontent-airvisual-web-c14]   .dropdown-container.xh300[_ngcontent-airvisual-web-c14]{max-height:300px}.search-container[_ngcontent-airvisual-web-c14]   .dropdown-container.overflow-y-scroll[_ngcontent-airvisual-web-c14]{overflow-y:scroll}.search-container[_ngcontent-airvisual-web-c14]   h3[_ngcontent-airvisual-web-c14]{font-size:12px;padding:0 24px;margin:18px 0 8px;text-transform:uppercase}@media only screen and (max-width:959px){.search-container[_ngcontent-airvisual-web-c14]   .dropdown-container[_ngcontent-airvisual-web-c14]{box-shadow:none;margin-top:0;border-top:1px solid #e6e6e6}.search-container[_ngcontent-airvisual-web-c14]   h3[_ngcontent-airvisual-web-c14]{padding:0 16px}}.search-container[_ngcontent-airvisual-web-c14]   .horizontal-line[_ngcontent-airvisual-web-c14]{height:1px;background-color:#e6e6e6;margin:12px 24px 4px 0}.search-container[_ngcontent-airvisual-web-c14]   .list.article-list[_ngcontent-airvisual-web-c14]{padding-top:8px}.search-container[_ngcontent-airvisual-web-c14]   .list[_ngcontent-airvisual-web-c14]   .item[_ngcontent-airvisual-web-c14]{padding:8px 24px}.search-container[_ngcontent-airvisual-web-c14]   .list[_ngcontent-airvisual-web-c14]   .item[_ngcontent-airvisual-web-c14]:hover{background:#eef2f6;cursor:pointer}.search-container[_ngcontent-airvisual-web-c14]   .list[_ngcontent-airvisual-web-c14]   .item.article-item[_ngcontent-airvisual-web-c14]{padding:10px 24px;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;line-height:1.43}.search-container[_ngcontent-airvisual-web-c14]   .list[_ngcontent-airvisual-web-c14]   .item.article-item[_ngcontent-airvisual-web-c14]   .article[_ngcontent-airvisual-web-c14]{white-space:nowrap;overflow:hidden;text-overflow:ellipsis;line-height:1.43}.search-container[_ngcontent-airvisual-web-c14]   .list[_ngcontent-airvisual-web-c14]   .item.article-item[_ngcontent-airvisual-web-c14]   .article.article-title[_ngcontent-airvisual-web-c14]{margin-bottom:4px}.search-container[_ngcontent-airvisual-web-c14]   .list[_ngcontent-airvisual-web-c14]   .item[_ngcontent-airvisual-web-c14]   .icon[_ngcontent-airvisual-web-c14]   img[_ngcontent-airvisual-web-c14]{width:24px;height:24px}.search-container[_ngcontent-airvisual-web-c14]   .list[_ngcontent-airvisual-web-c14]   .item[_ngcontent-airvisual-web-c14]   .follower[_ngcontent-airvisual-web-c14]{color:#67788d}.search-container[_ngcontent-airvisual-web-c14]   .list[_ngcontent-airvisual-web-c14]   .item[_ngcontent-airvisual-web-c14]   .thumbnail-contributor[_ngcontent-airvisual-web-c14]{width:40px;height:40px;border-radius:20px;-o-object-fit:cover;object-fit:cover}.search-container[_ngcontent-airvisual-web-c14]   .list[_ngcontent-airvisual-web-c14]   .item[_ngcontent-airvisual-web-c14]   .thumbnail-publication[_ngcontent-airvisual-web-c14]{width:80px;height:80px;-o-object-fit:cover;object-fit:cover}.search-container[_ngcontent-airvisual-web-c14]   .list[_ngcontent-airvisual-web-c14]   .item[_ngcontent-airvisual-web-c14]   .name[_ngcontent-airvisual-web-c14]{display:block!important;white-space:nowrap;overflow:hidden;text-overflow:ellipsis}.search-container[_ngcontent-airvisual-web-c14]   .list[_ngcontent-airvisual-web-c14]   .item[_ngcontent-airvisual-web-c14]   .aqi[_ngcontent-airvi ...
#   </style>
#   <style>
#    .category[_ngcontent-airvisual-web-c15]{width:204px}.category[_ngcontent-airvisual-web-c15]   .isProduct[_ngcontent-airvisual-web-c15]   .category-item[_ngcontent-airvisual-web-c15]:first-child{border-top:none}.category[_ngcontent-airvisual-web-c15]   h4[_ngcontent-airvisual-web-c15]{font-size:28px;font-weight:500;margin-bottom:32px}.category[_ngcontent-airvisual-web-c15]   .category-item[_ngcontent-airvisual-web-c15]{font-weight:500;width:100%;display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-ms-flex-pack:justify;justify-content:space-between;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:8px 0;border-top:1px solid rgba(0,0,0,.24);font-size:16px;color:#414141;cursor:pointer}.category[_ngcontent-airvisual-web-c15]   .category-item.active[_ngcontent-airvisual-web-c15], .category[_ngcontent-airvisual-web-c15]   .category-item[_ngcontent-airvisual-web-c15]:active, .category[_ngcontent-airvisual-web-c15]   .category-item[_ngcontent-airvisual-web-c15]:hover{font-weight:700}.category[_ngcontent-airvisual-web-c15]   .category-item[_ngcontent-airvisual-web-c15]:last-child{border-bottom:1px solid rgba(0,0,0,.24)}.category[_ngcontent-airvisual-web-c15]   .category-item[_ngcontent-airvisual-web-c15]   span[_ngcontent-airvisual-web-c15]{-webkit-box-flex:1;-ms-flex:1 1 auto;flex:1 1 auto;padding-right:10px}.category[_ngcontent-airvisual-web-c15]   .category-item[_ngcontent-airvisual-web-c15]   svg[_ngcontent-airvisual-web-c15]{width:18px;height:18px;min-width:18px;min-height:18px}
#   </style>
#   <style>
#    .item-grid[_ngcontent-airvisual-web-c16]{-webkit-box-ordinal-group:3;-ms-flex-order:2;order:2;-webkit-box-flex:1;-ms-flex:1 1 auto;flex:1 1 auto;padding:0 24px 0 16px;display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-ms-flex-pack:justify;justify-content:space-between;-webkit-box-align:stretch;-ms-flex-align:stretch;align-items:stretch;height:100%;min-height:624px}.item-grid[_ngcontent-airvisual-web-c16]   .multiple[_ngcontent-airvisual-web-c16], .item-grid[_ngcontent-airvisual-web-c16]   .single[_ngcontent-airvisual-web-c16]{margin-left:24px}.item-grid[_ngcontent-airvisual-web-c16]   .single[_ngcontent-airvisual-web-c16]{-webkit-box-flex:1;-ms-flex:1 1 auto;flex:1 1 auto;width:342px}.item-grid[_ngcontent-airvisual-web-c16]   .single[_ngcontent-airvisual-web-c16]   .item.isProduct.layout1[_ngcontent-airvisual-web-c16]   .bg-image[_ngcontent-airvisual-web-c16]{-o-object-fit:none;object-fit:none}.item-grid[_ngcontent-airvisual-web-c16]   .single[_ngcontent-airvisual-web-c16]   .item.isProduct.layout1[_ngcontent-airvisual-web-c16]   h5[_ngcontent-airvisual-web-c16]{font-size:28px}.item-grid[_ngcontent-airvisual-web-c16]   .single[_ngcontent-airvisual-web-c16]   .item.isProduct.layout1[_ngcontent-airvisual-web-c16]   p[_ngcontent-airvisual-web-c16]{font-size:18px}.item-grid[_ngcontent-airvisual-web-c16]   .multiple[_ngcontent-airvisual-web-c16]{-webkit-box-flex:1;-ms-flex:1 1 auto;flex:1 1 auto;width:464px;-ms-flex-wrap:wrap;flex-wrap:wrap;display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-ms-flex-pack:justify;justify-content:space-between;-webkit-box-align:stretch;-ms-flex-align:stretch;align-items:stretch;margin-bottom:-24px}.item-grid[_ngcontent-airvisual-web-c16]   .multiple.layout1[_ngcontent-airvisual-web-c16]{margin-bottom:0}.item-grid[_ngcontent-airvisual-web-c16]   .multiple.layout1[_ngcontent-airvisual-web-c16]   .item[_ngcontent-airvisual-web-c16]{width:100%;height:100%}.item-grid[_ngcontent-airvisual-web-c16]   .multiple.layout1[_ngcontent-airvisual-web-c16]   .item[_ngcontent-airvisual-web-c16]:first-child{display:block}.item-grid[_ngcontent-airvisual-web-c16]   .multiple.layout2[_ngcontent-airvisual-web-c16]{margin-bottom:0}.item-grid[_ngcontent-airvisual-web-c16]   .multiple.layout2[_ngcontent-airvisual-web-c16]   .item[_ngcontent-airvisual-web-c16]:nth-child(2){width:342px!important;height:100%!important}.item-grid[_ngcontent-airvisual-web-c16]   .multiple.layout2[_ngcontent-airvisual-web-c16]   .item[_ngcontent-airvisual-web-c16]:nth-child(2):hover   .bg-image[_ngcontent-airvisual-web-c16]{-webkit-transform:translate(-50%,-50%) scale(1.1);-ms-transform:translate(-50%,-50%) scale(1.1);transform:translate(-50%,-50%) scale(1.1)}.item-grid[_ngcontent-airvisual-web-c16]   .multiple.layout2[_ngcontent-airvisual-web-c16]   .item[_ngcontent-airvisual-web-c16]:nth-child(2)   .bg-image[_ngcontent-airvisual-web-c16]{-webkit-transform:translate(-50%,-50%);-ms-transform:translate(-50%,-50%);transform:translate(-50%,-50%)}.item-grid[_ngcontent-airvisual-web-c16]   .multiple.layout6[_ngcontent-airvisual-web-c16]{-webkit-box-flex:1;-ms-flex:1 1 auto;flex:1 1 auto;width:100%;padding-right:122px}.item-grid[_ngcontent-airvisual-web-c16]   .multiple.layout6[_ngcontent-airvisual-web-c16]   .item[_ngcontent-airvisual-web-c16]:first-child{display:block}.item-grid[_ngcontent-airvisual-web-c16]   .multiple[_ngcontent-airvisual-web-c16]   .item[_ngcontent-airvisual-web-c16]{width:220px;height:300px;margin-bottom:24px}.item-grid[_ngcontent-airvisual-web-c16]   .multiple[_ngcontent-airvisual-web-c16]   .item[_ngcontent-airvisual-web-c16]:first-child{display:none}.item-grid[_ngcontent-airvisual-web-c16]   .multiple[_ngcontent-airvisual-web-c16]   .item[_ngcontent-airvisual-web-c16]:nth-child(2){width:100%}.item-grid[_ngcontent-airvisual-web-c16]   .multiple[_ngcontent-airvisual-web-c16]   .item.isCommunity[_ngcontent-airvisual-web-c16]{padding:96px 96px 48px;text-align:center;display: ...
#   </style>
#   <style>
#    .news-layout[_ngcontent-airvisual-web-c17]{width:342px;height:100%;position:relative}.news-layout[_ngcontent-airvisual-web-c17]   .bottom-link[_ngcontent-airvisual-web-c17]{position:absolute;bottom:0;left:0;text-transform:uppercase;display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-pack:start;-ms-flex-pack:start;justify-content:flex-start;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:12px;letter-spacing:1.2px;font-weight:700;color:#456e98}.news-layout[_ngcontent-airvisual-web-c17]   .bottom-link[_ngcontent-airvisual-web-c17]   svg[_ngcontent-airvisual-web-c17]{width:24px;height:24px;margin-right:8px}.news-media[_ngcontent-airvisual-web-c17]{position:relative}.news-media[_ngcontent-airvisual-web-c17]   img[_ngcontent-airvisual-web-c17]{width:100%;height:228px;-o-object-fit:cover;object-fit:cover}.news-media[_ngcontent-airvisual-web-c17]   h5[_ngcontent-airvisual-web-c17]{position:absolute;top:16px;left:16px;font-size:18px;color:#fff}.news-items[_ngcontent-airvisual-web-c17]   a[_ngcontent-airvisual-web-c17]{padding:16px 0;border-bottom:1px solid rgba(0,0,0,.24);color:#414141;font-weight:500;font-size:18px;display:block}.news-items[_ngcontent-airvisual-web-c17]   a[_ngcontent-airvisual-web-c17]:active, .news-items[_ngcontent-airvisual-web-c17]   a[_ngcontent-airvisual-web-c17]:hover{font-weight:700}.news-items[_ngcontent-airvisual-web-c17]   a[_ngcontent-airvisual-web-c17]:first-child{font-size:24px;font-weight:700}.news-items[_ngcontent-airvisual-web-c17]   a[_ngcontent-airvisual-web-c17]:first-child:hover{color:#4db1cf}@media screen and (min-width:1140px) and (max-width:1479px){.news-layout[_ngcontent-airvisual-web-c17]{width:100%;height:410px}.news-items[_ngcontent-airvisual-web-c17]   a[_ngcontent-airvisual-web-c17]{padding:8px 0;font-size:14px}.news-items[_ngcontent-airvisual-web-c17]   a[_ngcontent-airvisual-web-c17]:first-child{font-size:17px}.news-media[_ngcontent-airvisual-web-c17]   img[_ngcontent-airvisual-web-c17]{height:200px}}
#   </style>
#   <style>
#    .banner[_ngcontent-airvisual-web-c18]{width:342px;height:100%;display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-orient:vertical;-webkit-box-direction:normal;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:start;-ms-flex-pack:start;justify-content:flex-start;-webkit-box-align:stretch;-ms-flex-align:stretch;align-items:stretch}.banner[_ngcontent-airvisual-web-c18]   .main-item[_ngcontent-airvisual-web-c18]{background:#2b353f;color:#fff;position:relative;-webkit-box-flex:1;-ms-flex:1 1 auto;flex:1 1 auto;text-align:center;padding:44px 48px 48px;margin-bottom:24px}.banner[_ngcontent-airvisual-web-c18]   .main-item[_ngcontent-airvisual-web-c18]   h5[_ngcontent-airvisual-web-c18]{font-size:28px;font-weight:500px;color:#fff;margin-bottom:16px}.banner[_ngcontent-airvisual-web-c18]   .main-item[_ngcontent-airvisual-web-c18]   p[_ngcontent-airvisual-web-c18]{font-size:18px;color:#fff}.banner[_ngcontent-airvisual-web-c18]   .main-item[_ngcontent-airvisual-web-c18]   a[_ngcontent-airvisual-web-c18]{position:absolute;bottom:48px;left:50%;-webkit-transform:translateX(-50%);-ms-transform:translateX(-50%);transform:translateX(-50%);padding:0 32px;height:48px;background:#60b3cf;border-radius:5px;font-size:12px;font-weight:700;letter-spacing:1.2px;color:#fff;text-transform:uppercase;display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-ms-flex-pack:center;justify-content:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center}.banner[_ngcontent-airvisual-web-c18]   .mini-item[_ngcontent-airvisual-web-c18]{display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-ms-flex-pack:justify;justify-content:space-between;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:0 16px;margin-bottom:16px;height:68px;box-shadow:0 2px 12px 0 rgba(0,0,0,.12)}.banner[_ngcontent-airvisual-web-c18]   .mini-item[_ngcontent-airvisual-web-c18]:last-child{margin-bottom:0}.banner[_ngcontent-airvisual-web-c18]   .mini-item[_ngcontent-airvisual-web-c18]   .end-icon[_ngcontent-airvisual-web-c18], .banner[_ngcontent-airvisual-web-c18]   .mini-item[_ngcontent-airvisual-web-c18]   .start-icon[_ngcontent-airvisual-web-c18]{width:24px;height:24px}.banner[_ngcontent-airvisual-web-c18]   .mini-item[_ngcontent-airvisual-web-c18]   span[_ngcontent-airvisual-web-c18]{padding:0 16px;text-align:left;-webkit-box-flex:1;-ms-flex:1 1 auto;flex:1 1 auto;font-size:16px;font-weight:500}.banner[_ngcontent-airvisual-web-c18]   .talkExpert[_ngcontent-airvisual-web-c18]{height:218px;display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-orient:vertical;-webkit-box-direction:normal;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:start;-ms-flex-pack:start;justify-content:flex-start;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:24px;text-align:center}.banner[_ngcontent-airvisual-web-c18]   .talkExpert[_ngcontent-airvisual-web-c18]   img[_ngcontent-airvisual-web-c18]{width:64px;height:64px}.banner[_ngcontent-airvisual-web-c18]   .talkExpert[_ngcontent-airvisual-web-c18]   h5[_ngcontent-airvisual-web-c18]{font-size:24px;font-weight:600;margin-top:15px}.banner[_ngcontent-airvisual-web-c18]   .talkExpert[_ngcontent-airvisual-web-c18]   p[_ngcontent-airvisual-web-c18]{font-size:16px;margin-top:8px}@media screen and (min-width:1140px) and (max-width:1479px){.banner[_ngcontent-airvisual-web-c18]{min-height:335px}.banner[_ngcontent-airvisual-web-c18]   .main-item[_ngcontent-airvisual-web-c18]   p[_ngcontent-airvisual-web-c18]{line-height:1.3}.banner[_ngcontent-airvisual-web-c18]   .main-item[_ngcontent-airvisual-web-c18]   a[_ngcontent-airvisual-web-c18]{bottom:30px}.banner[_ngcontent-airvisual-web-c18]   .main-item-products[_ngcontent-airvisual-web-c18]{padding:23px 32px 32px;margin-bottom:18px}.banner[_ngcontent-airvisual-web-c18]   .main-item-products[_ngcontent-airvisual-web-c18]   a[_ngcontent-airvisual-web-c18]{bottom:20px}.banne ...
#   </style>
#   <style>
#    .page-header[_ngcontent-airvisual-web-c22]{margin-bottom:12px}.page-header-title[_ngcontent-airvisual-web-c22]{margin-bottom:5px}.page-header-date-time-zone[_ngcontent-airvisual-web-c22]{line-height:1.75;color:#5b7186}.app-map-world[_ngcontent-airvisual-web-c22]{height:500px;background:#ddd}.more-news[_ngcontent-airvisual-web-c22]{width:99%;text-transform:uppercase;font-size:14px;font-weight:600;text-align:right;letter-spacing:1.2px}.more-news[_ngcontent-airvisual-web-c22]   a[_ngcontent-airvisual-web-c22]{color:#49739a}@media only screen and (max-width:599px){.app-map-world[_ngcontent-airvisual-web-c22]{height:320px}}
#   </style>
#   <style>
#    .header[_ngcontent-airvisual-web-c24]{padding:48px 0}.header[_ngcontent-airvisual-web-c24]   h1.slogan[_ngcontent-airvisual-web-c24]{font-size:42px;font-style:normal;font-stretch:normal;line-height:normal;letter-spacing:normal;color:#414141}.header[_ngcontent-airvisual-web-c24]   h1.slogan[_ngcontent-airvisual-web-c24]   span.slogan-title[_ngcontent-airvisual-web-c24]{display:block;font-weight:700;margin-bottom:5px}.header[_ngcontent-airvisual-web-c24]   h1.slogan[_ngcontent-airvisual-web-c24]   span.slogan-subtitle[_ngcontent-airvisual-web-c24]{display:block;font-weight:300}.search-home-page[_ngcontent-airvisual-web-c24]{position:relative;z-index:999}.search-home-page[_ngcontent-airvisual-web-c24]   .search-form[_ngcontent-airvisual-web-c24]{border-radius:6px;box-shadow:0 1px 4px 0 rgba(0,0,0,.2);border:1px solid #e6e6e6;background:#fff}.search-home-page[_ngcontent-airvisual-web-c24]   .search-form.focused[_ngcontent-airvisual-web-c24]{border-radius:6px 6px 0 0;border:2px solid #ccd4e0}.search-home-page[_ngcontent-airvisual-web-c24]   .search-form[_ngcontent-airvisual-web-c24]   .input[_ngcontent-airvisual-web-c24]   input[_ngcontent-airvisual-web-c24]{background:0 0;border:none;height:56px;width:100%;font-size:16px;padding:16px 24px;color:#414141;font-weight:500}.search-home-page[_ngcontent-airvisual-web-c24]   .search-form[_ngcontent-airvisual-web-c24]   .input[_ngcontent-airvisual-web-c24]   input[_ngcontent-airvisual-web-c24]::-webkit-input-placeholder{color:#606060}.search-home-page[_ngcontent-airvisual-web-c24]   .search-form[_ngcontent-airvisual-web-c24]   .input[_ngcontent-airvisual-web-c24]   input[_ngcontent-airvisual-web-c24]::-moz-placeholder{color:#606060}.search-home-page[_ngcontent-airvisual-web-c24]   .search-form[_ngcontent-airvisual-web-c24]   .input[_ngcontent-airvisual-web-c24]   input[_ngcontent-airvisual-web-c24]:-ms-input-placeholder{color:#606060}.search-home-page[_ngcontent-airvisual-web-c24]   .search-form[_ngcontent-airvisual-web-c24]   .input[_ngcontent-airvisual-web-c24]   input[_ngcontent-airvisual-web-c24]::-ms-input-placeholder{color:#606060}.search-home-page[_ngcontent-airvisual-web-c24]   .search-form[_ngcontent-airvisual-web-c24]   .input[_ngcontent-airvisual-web-c24]   input[_ngcontent-airvisual-web-c24]::placeholder{color:#606060}.search-home-page[_ngcontent-airvisual-web-c24]   .search-form[_ngcontent-airvisual-web-c24]   .input[_ngcontent-airvisual-web-c24]   input[_ngcontent-airvisual-web-c24]:focus{outline:0;box-shadow:none}.search-home-page[_ngcontent-airvisual-web-c24]   .search-form[_ngcontent-airvisual-web-c24]   .input[_ngcontent-airvisual-web-c24]   input[_ngcontent-airvisual-web-c24]::-ms-clear{display:none}.search-home-page[_ngcontent-airvisual-web-c24]   .search-form[_ngcontent-airvisual-web-c24]   .icon[_ngcontent-airvisual-web-c24]{padding:12px 16px}.search-home-page[_ngcontent-airvisual-web-c24]   .search-form[_ngcontent-airvisual-web-c24]   .icon[_ngcontent-airvisual-web-c24]   img[_ngcontent-airvisual-web-c24]{width:32px;height:32px}.search-home-page[_ngcontent-airvisual-web-c24]   .search-form[_ngcontent-airvisual-web-c24]   .icon[_ngcontent-airvisual-web-c24]   img.ic-clear[_ngcontent-airvisual-web-c24]{cursor:pointer}.locate-me[_ngcontent-airvisual-web-c24]   button[_ngcontent-airvisual-web-c24]{background:0 0;border:none;cursor:pointer;width:60px;height:60px;border-radius:100%;box-shadow:2px 2px 10px 0 rgba(0,0,0,.1);overflow:hidden}.locate-me[_ngcontent-airvisual-web-c24]   button[_ngcontent-airvisual-web-c24]   img[_ngcontent-airvisual-web-c24]{width:100%;height:100%}.overlay[_ngcontent-airvisual-web-c24]{position:fixed;display:none;width:100%;height:100%;top:0;left:0;right:0;bottom:0;background-color:rgba(0,0,0,.5);z-index:1000;cursor:pointer}@media only screen and (max-width:959px){.header[_ngcontent-airvisual-web-c24]   .search[_ngcontent-airvisual-web-c24]{margin-top:16px}.header[_ngcontent-airvisual-web-c24]   h1.slogan[_ngcontent-airvisual-web-c24]{font-siz ...
#   </style>
#   <style>
# ...
#               </div>
#               <div class="mat-button-focus-overlay">
#               </div>
#              </button>
#             </form>
#            </div>
#           </div>
#           <div _ngcontent-airvisual-web-c13="" class="section-1-right">
#            <!-- -->
#            <a _ngcontent-airvisual-web-c13="" class="section-1-right-img ng-star-inserted" href="https://www.facebook.com/iqair/" target="_blank">
#             <img _ngcontent-airvisual-web-c13="" alt="" src="assets/svg/ic-social-facebook-round.svg"/>
#            </a>
#            <a _ngcontent-airvisual-web-c13="" class="section-1-right-img ng-star-inserted" href="https://www.instagram.com/iqair/" target="_blank">
#             <img _ngcontent-airvisual-web-c13="" alt="" src="assets/icons/ic-social-instagram-round.jpg"/>
#            </a>
#            <a _ngcontent-airvisual-web-c13="" class="section-1-right-img ng-star-inserted" href="https://www.youtube.com/user/IQAir" target="_blank">
#             <img _ngcontent-airvisual-web-c13="" alt="" src="assets/icons/ic-social-youtube-round.jpg"/>
#            </a>
#            <a _ngcontent-airvisual-web-c13="" class="section-1-right-img ng-star-inserted" href="https://twitter.com/IQAir" target="_blank">
#             <img _ngcontent-airvisual-web-c13="" alt="" src="assets/svg/ic-social-twitter-round.svg"/>
#            </a>
#           </div>
#          </div>
#          <div _ngcontent-airvisual-web-c13="" class="section-2">
#           <div _ngcontent-airvisual-web-c13="" class="section-2-left">
#            @ Copyright 2020 IQAir. All rights reserved.
#           </div>
#           <div _ngcontent-airvisual-web-c13="" class="section-2-center">
#            <a _ngcontent-airvisual-web-c13="" class="section-2-center-item" href="/legal/trademark-list">
#             Trademarks
#            </a>
#            <a _ngcontent-airvisual-web-c13="" class="section-2-center-item" href="/legal/terms-conditions">
#             Terms and Conditions
#            </a>
#            <a _ngcontent-airvisual-web-c13="" class="section-2-center-item" href="/legal/notice">
#             Legal Notice
#            </a>
#           </div>
#           <div _ngcontent-airvisual-web-c13="" class="section-2-right">
#            <!-- -->
#            <a _ngcontent-airvisual-web-c13="" class="section-2-right-img ng-star-inserted" href="https://www.facebook.com/iqair/" target="_blank">
#             <img _ngcontent-airvisual-web-c13="" alt="" src="assets/svg/ic-social-facebook-round.svg"/>
#            </a>
#            <a _ngcontent-airvisual-web-c13="" class="section-2-right-img ng-star-inserted" href="https://www.instagram.com/iqair/" target="_blank">
#             <img _ngcontent-airvisual-web-c13="" alt="" src="assets/icons/ic-social-instagram-round.jpg"/>
#            </a>
#            <a _ngcontent-airvisual-web-c13="" class="section-2-right-img ng-star-inserted" href="https://www.youtube.com/user/IQAir" target="_blank">
#             <img _ngcontent-airvisual-web-c13="" alt="" src="assets/icons/ic-social-youtube-round.jpg"/>
#            </a>
#            <a _ngcontent-airvisual-web-c13="" class="section-2-right-img ng-star-inserted" href="https://twitter.com/IQAir" target="_blank">
#             <img _ngcontent-airvisual-web-c13="" alt="" src="assets/svg/ic-social-twitter-round.svg"/>
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#       </app-footer-intl>
#      </div>
#     </app-footer>
#    </app-portal>
#    <app-site-cookie-dialog _ngcontent-airvisual-web-c0="" _nghost-airvisual-web-c1="">
#     <!-- -->
#     <div _ngcontent-airvisual-web-c1="" class="site-cookie-container">
#      <div _ngcontent-airvisual-web-c1="" class="site-cookie container">
#       <div _ngcontent-airvisual-web-c1="" class="description">
#        <p _ngcontent-airvisual-web-c1="">
#         IQAir sites use cookies to improve your online experience and deliver advertisements tailored to your interests. Click “I CONSENT” below if you consent to our use of cookies for these purposes. For more information about our how we use cookies, including how to manage your cookie settings, please review our
#         <a _ngcontent-airvisual-web-c1="" href="/legal/privacy-policy">
#          Privacy Policy
#         </a>
#         .
#        </p>
#       </div>
#       <div _ngcontent-airvisual-web-c1="" class="button-container">
#        <button _ngcontent-airvisual-web-c1="" class="btnAccept" type="button">
#         I CONSENT
#        </button>
#       </div>
#       <button _ngcontent-airvisual-web-c1="" class="btnClose" type="button">
#        <img _ngcontent-airvisual-web-c1="" alt="clear icon" src="assets/svg/ic-clear-small-white.svg"/>
#       </button>
#      </div>
#     </div>
#    </app-site-cookie-dialog>
#   </app-root>
#   <script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-PPQMD6">
#   </script>
#   <script src="/assets/iqair/js/buy-button-storefront.min.js">
#   </script>
#   <!-- Google Tag Manager (noscript) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-PPQMD6" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#       new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#       j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#       'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#       })(window,document,'script','dataLayer','GTM-PPQMD6');
#   </script>
#   <!-- End Google Tag Manager (noscript) -->
#   <!-- Facebook Pixel Code -->
#   <noscript>
#    <img height="1" src="https://www.facebook.com/tr?id=476595546403287&amp;ev=PageView&amp;noscript=1" width="1">
#    </img>
#   </noscript>
#   <!-- End Facebook Pixel Code -->
#   <script crossorigin="" src="runtime-es2015.283a9eb3f2864f76d4db.js" type="module">
#   </script>
#   <script crossorigin="" src="polyfills-es2015.5ef34295898a1854808e.js" type="module">
#   </script>
#   <script defer="" nomodule="" src="runtime-es5.4bd767055127f9a1fa64.js">
#   </script>
#   <script defer="" nomodule="" src="polyfills-es5.650a001cedfc6bcbee59.js">
#   </script>
#   <script crossorigin="" src="vendor-es2015.b158ccf35c7b809a13ac.js" type="module">
#   </script>
#   <script crossorigin="" src="main-es2015.f67f267b52bc37146ff4.js" type="module">
#   </script>
#   <script defer="" nomodule="" src="vendor-es5.2022343fe91e37e4958d.js">
#   </script>
#   <script defer="" nomodule="" src="main-es5.5e804adf03eca2afb020.js">
#   </script>
#   <script id="airvisual-web-state" type="application/json">
#    {&q;X_REAL_IP&q;:&q;10.120.52.231&q;,&q;https://website-api.airvisual.com/v1/countries/rankingsperPage=10&a;display=full&a;units.temperature=celsius&a;units.distance=kilometer&a;AQI=US&a;language=en&q;:[{&q;city&q;:&q;Johannesburg&q;,&q;country&q;:&q;South Africa&q;,&q;id&q;:&q;5bac89ca24b967f0b5308109&q;,&q;url&q;:&q;/south-africa/gauteng/johannesburg&q;,&q;aqi&q;:131,&q;flagURL&q;:&q;https://cdn.airvisual.net/flags/south-africa.jpg&q;,&q;followersCount&q;:14863,&q;updatedAt&q;:&q;2020-06-16T12:00:00.000Z&q;,&q;rank&q;:1},{&q;city&q;:&q;Shenzhen&q;,&q;country&q;:&q;China&q;,&q;id&q;:&q;5yaBSXkSwfSJCqQbT&q;,&q;url&q;:&q;/china/guangdong/shenzhen&q;,&q;aqi&q;:129,&q;flagURL&q;:&q;https://cdn.airvisual.net/flags/china.jpg&q;,&q;followersCount&q;:158359,&q;updatedAt&q;:&q;2020-06-16T11:00:00.000Z&q;,&q;rank&q;:2},{&q;city&q;:&q;Seoul&q;,&q;country&q;:&q;South Korea&q;,&q;id&q;:&q;2rwQKsaAs2MnT8bBQ&q;,&q;url&q;:&q;/south-korea/seoul&q;,&q;aqi&q;:129,&q;flagURL&q;:&q;https://cdn.airvisual.net/flags/south-korea.jpg&q;,&q;followersCount&q;:6581483,&q;updatedAt&q;:&q;2020-06-16T12:00:00.000Z&q;,&q;rank&q;:3},{&q;city&q;:&q;Tehran&q;,&q;country&q;:&q;Iran&q;,&q;id&q;:&q;NpERe99SqzPjF5Gdi&q;,&q;url&q;:&q;/iran/tehran&q;,&q;aqi&q;:116,&q;flagURL&q;:&q;https://cdn.airvisual.net/flags/iran.jpg&q;,&q;followersCount&q;:237646,&q;updatedAt&q;:&q;2020-06-16T11:00:00.000Z&q;,&q;rank&q;:4},{&q;city&q;:&q;Hangzhou&q;,&q;country&q;:&q;China&q;,&q;id&q;:&q;pk2aFhypdgQLhm6xn&q;,&q;url&q;:&q;/china/zhejiang/hangzhou&q;,&q;aqi&q;:112,&q;flagURL&q;:&q;https://cdn.airvisual.net/flags/china.jpg&q;,&q;followersCount&q;:136993,&q;updatedAt&q;:&q;2020-06-16T09:00:00.000Z&q;,&q;rank&q;:5},{&q;city&q;:&q;Jakarta&q;,&q;country&q;:&q;Indonesia&q;,&q;id&q;:&q;LembLiKtxzRZbDYP4&q;,&q;url&q;:&q;/indonesia/jakarta&q;,&q;aqi&q;:102,&q;flagURL&q;:&q;https://cdn.airvisual.net/flags/indonesia.jpg&q;,&q;followersCount&q;:2248567,&q;updatedAt&q;:&q;2020-06-16T12:00:00.000Z&q;,&q;rank&q;:6},{&q;city&q;:&q;Karachi&q;,&q;country&q;:&q;Pakistan&q;,&q;id&q;:&q;eT4pi8yRKPGwFY3y5&q;,&q;url&q;:&q;/pakistan/sindh/karachi&q;,&q;aqi&q;:94,&q;flagURL&q;:&q;https://cdn.airvisual.net/flags/pakistan.jpg&q;,&q;followersCount&q;:56458,&q;updatedAt&q;:&q;2020-06-16T12:00:00.000Z&q;,&q;rank&q;:7},{&q;city&q;:&q;Incheon&q;,&q;country&q;:&q;South Korea&q;,&q;id&q;:&q;7uuTKfARxDLwAsv3q&q;,&q;url&q;:&q;/south-korea/gyeonggi-do/incheon&q;,&q;aqi&q;:88,&q;flagURL&q;:&q;https://cdn.airvisual.net/flags/south-korea.jpg&q;,&q;followersCount&q;:73994,&q;updatedAt&q;:&q;2020-06-16T12:00:00.000Z&q;,&q;rank&q;:8},{&q;city&q;:&q;Kuwait City&q;,&q;country&q;:&q;Kuwait&q;,&q;id&q;:&q;fjyFSDBAk8ntyL9Kv&q;,&q;url&q;:&q;/kuwait/al-asimah/kuwait-city&q;,&q;aqi&q;:87,&q;flagURL&q;:&q;https://cdn.airvisual.net/flags/kuwait.jpg&q;,&q;followersCount&q;:31404,&q;updatedAt&q;:&q;2020-06-16T12:00:00.000Z&q;,&q;rank&q;:9},{&q;city&q;:&q;Delhi&q;,&q;country&q;:&q;India&q;,&q;id&q;:&q;ceJrHNhXup9KtZTvQ&q;,&q;url&q;:&q;/india/delhi&q;,&q;aqi&q;:86,&q;flagURL&q;:&q;https://cdn.airvisual.net/flags/india.jpg&q;,&q;followersCount&q;:2474272,&q;updatedAt&q;:&q;2020-06-16T12:00:00.000Z&q;,&q;rank&q;:10}],&q;G.https://website-api.airvisual.com/v1/countries/rankings?display=full&a;perPage=10&q;:{&q;body&q;:[{&q;city&q;:&q;Johannesburg&q;,&q;country&q;:&q;South Africa&q;,&q;id&q;:&q;5bac89ca24b967f0b5308109&q;,&q;url&q;:&q;/south-africa/gauteng/johannesburg&q;,&q;aqi&q;:131,&q;flagURL&q;:&q;https://cdn.airvisual.net/flags/south-africa.jpg&q;,&q;followersCount&q;:14863,&q;updatedAt&q;:&q;2020-06-16T12:00:00.000Z&q;,&q;rank&q;:1},{&q;city&q;:&q;Shenzhen&q;,&q;country&q;:&q;China&q;,&q;id&q;:&q;5yaBSXkSwfSJCqQbT&q;,&q;url&q;:&q;/china/guangdong/shenzhen&q;,&q;aqi&q;:129,&q;flagURL&q;:&q;https://cdn.airvisual.net/flags/china.jpg&q;,&q;followersCount&q;:158359,&q;updatedAt&q;:&q;2020-06-16T11:00:00.000Z&q;,&q;rank&q;:2},{&q;city&q;:&q;Seoul&q;,&q;country&q;:&q;South Korea&q;,&q;id&q;:&q;2rwQKsaAs2MnT8bBQ&q;,&q;url&q;:&q;/south-kore ...
#   </script>
#   <script id="" type="text/javascript">
#    !function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","https://connect.facebook.net/en_US/fbevents.js");fbq("init","463163240733630");fbq("set","agent","tmgoogletagmanager","463163240733630");fbq("track","PageView");
#   </script>
#   <noscript>
#    <img height="1" src="https://www.facebook.com/tr?id=463163240733630&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
#   </noscript>
#   <script id="" type="text/javascript">
#    var referralPeriod=365,url=window.location.href,cjEvent,isCjCookiePresent=!1;if(url.includes("cjevent")){var start=url.indexOf("cjevent"),end=url.length,query=url.substring(start,end),newEnd=query.indexOf("\x26");-1==newEnd&&(newEnd=query.length);cjEvent=query.substring(8,newEnd);checkForCjCookie()}
# function checkForCjCookie(){var d="cjevent\x3d",c=decodeURIComponent(document.cookie);c=c.split(";");for(var b=0;b<c.length;b++){for(var a=c[b];" "==a.charAt(0);)a=a.substring(1);0==a.indexOf(d)&&(a=a.substring(d.length),void 0!=cjEvent?(isCjCookiePresent=!0,updateCookie()):void 0!=a&&setCjCookie("cjevent",a,referralPeriod))}void 0==cjEvent||isCjCookiePresent||setCjCookie("cjevent",cjEvent,referralPeriod)}
# function setCjCookie(d,c,b){var a=new Date;a.setTime(a.getTime()+864E5*b);b="expires\x3d"+a.toUTCString();document.cookie=d+"\x3d"+c+";"+b+";domain\x3diqair.com;path\x3d/"}function updateCookie(){isCjCookiePresent&&(setCjCookie("cjevent","",-1),setCjCookie("cjevent",cjEvent,referralPeriod))};
#   </script>
#   <script id="" type="text/javascript">
#    !function(c,d){var a=window.bronto=function(){"string"==typeof arguments[0]&&a.q.push(arguments);a.go&&a.go()};a.q=a.q||[];var b=c.createElement(d),e=c.getElementsByTagName(d)[0];e.parentNode.insertBefore(b,e);b.async=!0;b.onload=a;b.src="https://snip.bronto.com/v2/sites/eyJ0eXBlIjoic2l0ZWhhc2giLCJpZCI6ImMzZmRjYWNlZmRmZThlOTIyZjJiNzZmNjM3MGUwNmIzMTIxMzM0ZGRlMjNjMDMwMmE3ZGU5NmU2MGZlNGI4ZTkifQ\x3d\x3d/assets/bundle.js"}(document,"script");
#   </script>
#   <script id="" type="text/javascript">
#    var set_int=setInterval(function(){jQuery('p:contains("Your checklist will be in your inbox shortly")').is(":visible")&&(dataLayer.push({event:"form_submit"}),clearInterval(setInt))},1E3);
#   </script>
#   <div aria-atomic="true" aria-live="polite" class="cdk-live-announcer-element cdk-visually-hidden">
#   </div>
#   <div id="batBeacon0.8924219591349041" style="width:0px; height:0px; display:none; visibility:hidden;">
#    <img alt="" height="0" id="batBeacon0.13246476500893856" src="https://bat.bing.com/action/0?ti=26072361&amp;Ver=2&amp;mid=1c32d312-1bea-317e-e055-57a1df11c73f&amp;sid=414a2c39-15ab-43c7-d7f2-ca5cd43a9d8c&amp;vid=add57db9-325d-34e4-76cc-4ef7690bb428-1&amp;pi=1200101525&amp;lg=en-US&amp;sw=1440&amp;sh=900&amp;sc=24&amp;tl=World%20Live%20Air%20Quality%20Map%20%7C%20AirVisual&amp;p=https%3A%2F%2Fwww.iqair.com%2Fworld-air-quality&amp;r=&amp;lt=4747&amp;evt=pageLoad&amp;msclkid=N&amp;sv=1&amp;rn=360148" style="width:0px; height:0px; display:none; visibility:hidden;" width="0"/>
#   </div>
#   <div class="shopify-buy-frame shopify-buy-frame--product">
#   </div>
#   <div class="shopify-buy-frame shopify-buy-frame--toggle is-sticky shopify-store-token-562553a05bddb7b166dfaeda25bdfd92">
#    <div class="is-sticky shopify-buy__cart-toggle">
#     <div class="shopify-buy__cart-toggle__count" data-element="toggle.count">
#      0
#     </div>
#     <svg class="shopify-buy__icon-cart shopify-buy__icon-cart--side" data-element="toggle.icon" enable-background="new 0 0 25 25" viewbox="0 0 25 25" xmlns="http://www.w3.org/2000/svg">
#      <g class="shopify-buy__icon-cart__group">
#       <path d="M24.6 3.6c-.3-.4-.8-.6-1.3-.6h-18.4l-.1-.5c-.3-1.5-1.7-1.5-2.5-1.5h-1.3c-.6 0-1 .4-1 1s.4 1 1 1h1.8l3 13.6c.2 1.2 1.3 2.4 2.5 2.4h12.7c.6 0 1-.4 1-1s-.4-1-1-1h-12.7c-.2 0-.5-.4-.6-.8l-.2-1.2h12.6c1.3 0 2.3-1.4 2.5-2.4l2.4-7.4v-.2c.1-.5-.1-1-.4-1.4zm-4 8.5v.2c-.1.3-.4.8-.5.8h-13l-1.8-8.1h17.6l-2.3 7.1z">
#       </path>
#       <circle cx="9" cy="22" r="2">
#       </circle>
#       <circle cx="19" cy="22" r="2">
#       </circle>
#      </g>
#     </svg>
#     <p class="shopify-buy--visually-hidden">
#      cart
#     </p>
#    </div>
#   </div>
#   <div class="shopify-buy-cart-wrapper shopify-buy-frame shopify-buy-frame--cart shopify-store-token-562553a05bddb7b166dfaeda25bdfd92">
#    <div class="shopify-buy__cart">
#     <div class="shopify-buy__cart__header" data-element="cart.header">
#      <h2 class="shopify-buy__cart__title" data-element="cart.title">
#       Cart
#      </h2>
#      <button class="shopify-buy__btn--close" data-element="cart.close">
#       <span aria-role="hidden">
#        ×
#       </span>
#       <span class="visuallyhidden">
#        Close
#       </span>
#      </button>
#     </div>
#     <div class="shopify-buy__cart-scroll" data-element="cart.cartScroll">
#      <p class="shopify-buy__cart-empty-text" data-element="cart.empty">
#       Your cart is empty
#      </p>
#      <div class="shopify-buy__cart-items" data-element="cart.lineItems">
#      </div>
#     </div>
#    </div>
#   </div>
#   <div aria-hidden="true" id="cdk-describedby-message-container" style="display: none;">
#    <div id="cdk-describedby-message-0">
#     Most polluted cities among major cities in the world
#    </div>
#   </div>
#  </body>
# </html>

# %%
country_url = []
tests = test_soup.find_all('div',class_ = 'name')
for test in tests:
    wocao = test.find('a')['href']
    country_url.append(f'https://www.iqair.com{wocao}')
# Out:
# [<div _ngcontent-airvisual-web-c26="" class="name" fxflex="" style="flex: 1 1 0%; box-sizing: border-box;"><!-- --><!-- --><a _ngcontent-airvisual-web-c26="" class="ng-star-inserted" href="/south-africa/gauteng/johannesburg"> Johannesburg, South Africa </a></div>, <div _ngcontent-airvisual-web-c26="" class="name" fxflex="" style="flex: 1 1 0%; box-sizing: border-box;"><!-- --><!-- --><a _ngcontent-airvisual-web-c26="" class="ng-star-inserted" href="/china/guangdong/shenzhen"> Shenzhen, China </a></div>, <div _ngcontent-airvisual-web-c26="" class="name" fxflex="" style="flex: 1 1 0%; box-sizing: border-box;"><!-- --><!-- --><a _ngcontent-airvisual-web-c26="" class="ng-star-inserted" href="/south-korea/seoul"> Seoul, South Korea </a></div>, <div _ngcontent-airvisual-web-c26="" class="name" fxflex="" style="flex: 1 1 0%; box-sizing: border-box;"><!-- --><!-- --><a _ngcontent-airvisual-web-c26="" class="ng-star-inserted" href="/iran/tehran"> Tehran, Iran </a></div>, <div _ngcontent-airvisual-web-c26="" class="name" fxflex="" style="flex: 1 1 0%; box-sizing: border-box;"><!-- --><!-- --><a _ngcontent-airvisual-web-c26="" class="ng-star-inserted" href="/china/zhejiang/hangzhou"> Hangzhou, China </a></div>, <div _ngcontent-airvisual-web-c26="" class="name" fxflex="" style="flex: 1 1 0%; box-sizing: border-box;"><!-- --><!-- --><a _ngcontent-airvisual-web-c26="" class="ng-star-inserted" href="/indonesia/jakarta"> Jakarta, Indonesia </a></div>, <div _ngcontent-airvisual-web-c26="" class="name" fxflex="" style="flex: 1 1 0%; box-sizing: border-box;"><!-- --><!-- --><a _ngcontent-airvisual-web-c26="" class="ng-star-inserted" href="/pakistan/sindh/karachi"> Karachi, Pakistan </a></div>, <div _ngcontent-airvisual-web-c26="" class="name" fxflex="" style="flex: 1 1 0%; box-sizing: border-box;"><!-- --><!-- --><a _ngcontent-airvisual-web-c26="" class="ng-star-inserted" href="/south-korea/gyeonggi-do/incheon"> Incheon, South Korea </a></div>, <div _ngcontent-airvisual-web-c26="" class="name" fxflex="" style="flex: 1 1 0%; box-sizing: border-box;"><!-- --><!-- --><a _ngcontent-airvisual-web-c26="" class="ng-star-inserted" href="/kuwait/al-asimah/kuwait-city"> Kuwait City, Kuwait </a></div>, <div _ngcontent-airvisual-web-c26="" class="name" fxflex="" style="flex: 1 1 0%; box-sizing: border-box;"><!-- --><!-- --><a _ngcontent-airvisual-web-c26="" class="ng-star-inserted" href="/india/delhi"> Delhi, India </a></div>]
# /south-africa/gauteng/johannesburg
# /china/guangdong/shenzhen
# /south-korea/seoul
# /iran/tehran
# /china/zhejiang/hangzhou
# /indonesia/jakarta
# /pakistan/sindh/karachi
# /south-korea/gyeonggi-do/incheon
# /kuwait/al-asimah/kuwait-city
# /india/delhi

# %%
country_url
# ['https://www.iqair.com/south-africa/gauteng/johannesburg',
#  'https://www.iqair.com/china/guangdong/shenzhen',
#  'https://www.iqair.com/south-korea/seoul',
#  'https://www.iqair.com/iran/tehran',
#  'https://www.iqair.com/china/zhejiang/hangzhou',
#  'https://www.iqair.com/indonesia/jakarta',
#  'https://www.iqair.com/pakistan/sindh/karachi',
#  'https://www.iqair.com/south-korea/gyeonggi-do/incheon',
#  'https://www.iqair.com/kuwait/al-asimah/kuwait-city',
#  'https://www.iqair.com/india/delhi']
# Out:
# ['https://www.iqair.com/south-africa/gauteng/johannesburg',
#  'https://www.iqair.com/china/guangdong/shenzhen',
#  'https://www.iqair.com/south-korea/seoul',
#  'https://www.iqair.com/iran/tehran',
#  'https://www.iqair.com/china/zhejiang/hangzhou',
#  'https://www.iqair.com/indonesia/jakarta',
#  'https://www.iqair.com/pakistan/sindh/karachi',
#  'https://www.iqair.com/south-korea/gyeonggi-do/incheon',
#  'https://www.iqair.com/kuwait/al-asimah/kuwait-city',
#  'https://www.iqair.com/india/delhi']

# %%
tables_cao = []

for x in country_url:
    table_soup = scrape_info(x)
    table_country = table_soup.find('table',class_ = 'aqi-overview-detail__main-pollution-table')
    tables_cao.append(str(table_country))
    # maybe weather

# %%
tables_cao
# Out:
# ['<table _ngcontent-airvisual-web-c35="" class="aqi-overview-detail__main-pollution-table" title="What is the current air quality in Johannesburg?"><thead _ngcontent-airvisual-web-c35=""><tr _ngcontent-airvisual-web-c35=""><th _ngcontent-airvisual-web-c35="">Air pollution level</th><th _ngcontent-airvisual-web-c35="">Air quality index</th><th _ngcontent-airvisual-web-c35="">Main pollutant</th></tr></thead><tbody _ngcontent-airvisual-web-c35=""><tr _ngcontent-airvisual-web-c35=""><td _ngcontent-airvisual-web-c35="">Unhealthy for Sensitive Groups</td><td _ngcontent-airvisual-web-c35="">140 <span _ngcontent-airvisual-web-c35="">US AQI</span></td><td _ngcontent-airvisual-web-c35="">PM2.5</td></tr></tbody></table>',
#  '<table _ngcontent-airvisual-web-c35="" class="aqi-overview-detail__main-pollution-table" title="What is the current air quality in Shenzhen?"><thead _ngcontent-airvisual-web-c35=""><tr _ngcontent-airvisual-web-c35=""><th _ngcontent-airvisual-web-c35="">Air pollution level</th><th _ngcontent-airvisual-web-c35="">Air quality index</th><th _ngcontent-airvisual-web-c35="">Main pollutant</th></tr></thead><tbody _ngcontent-airvisual-web-c35=""><tr _ngcontent-airvisual-web-c35=""><td _ngcontent-airvisual-web-c35="">Good</td><td _ngcontent-airvisual-web-c35="">21 <span _ngcontent-airvisual-web-c35="">US AQI</span></td><td _ngcontent-airvisual-web-c35="">PM2.5</td></tr></tbody></table>',
#  '<table _ngcontent-airvisual-web-c35="" class="aqi-overview-detail__main-pollution-table" title="What is the current air quality in Seoul?"><thead _ngcontent-airvisual-web-c35=""><tr _ngcontent-airvisual-web-c35=""><th _ngcontent-airvisual-web-c35="">Air pollution level</th><th _ngcontent-airvisual-web-c35="">Air quality index</th><th _ngcontent-airvisual-web-c35="">Main pollutant</th></tr></thead><tbody _ngcontent-airvisual-web-c35=""><tr _ngcontent-airvisual-web-c35=""><td _ngcontent-airvisual-web-c35="">Unhealthy for Sensitive Groups</td><td _ngcontent-airvisual-web-c35="">122 <span _ngcontent-airvisual-web-c35="">US AQI</span></td><td _ngcontent-airvisual-web-c35="">PM2.5</td></tr></tbody></table>',
#  '<table _ngcontent-airvisual-web-c35="" class="aqi-overview-detail__main-pollution-table" title="What is the current air quality in Tehran?"><thead _ngcontent-airvisual-web-c35=""><tr _ngcontent-airvisual-web-c35=""><th _ngcontent-airvisual-web-c35="">Air pollution level</th><th _ngcontent-airvisual-web-c35="">Air quality index</th><th _ngcontent-airvisual-web-c35="">Main pollutant</th></tr></thead><tbody _ngcontent-airvisual-web-c35=""><tr _ngcontent-airvisual-web-c35=""><td _ngcontent-airvisual-web-c35="">Moderate</td><td _ngcontent-airvisual-web-c35="">89 <span _ngcontent-airvisual-web-c35="">US AQI</span></td><td _ngcontent-airvisual-web-c35="">o3</td></tr></tbody></table>',
#  '<table _ngcontent-airvisual-web-c35="" class="aqi-overview-detail__main-pollution-table" title="What is the current air quality in Hangzhou?"><thead _ngcontent-airvisual-web-c35=""><tr _ngcontent-airvisual-web-c35=""><th _ngcontent-airvisual-web-c35="">Air pollution level</th><th _ngcontent-airvisual-web-c35="">Air quality index</th><th _ngcontent-airvisual-web-c35="">Main pollutant</th></tr></thead><tbody _ngcontent-airvisual-web-c35=""><tr _ngcontent-airvisual-web-c35=""><td _ngcontent-airvisual-web-c35="">Moderate</td><td _ngcontent-airvisual-web-c35="">74 <span _ngcontent-airvisual-web-c35="">US AQI</span></td><td _ngcontent-airvisual-web-c35="">PM2.5</td></tr></tbody></table>',
#  '<table _ngcontent-airvisual-web-c35="" class="aqi-overview-detail__main-pollution-table" title="What is the current air quality in Jakarta?"><thead _ngcontent-airvisual-web-c35=""><tr _ngcontent-airvisual-web-c35=""><th _ngcontent-airvisual-web-c35="">Air pollution level</th><th _ngcontent-airvisual-web-c35="">Air quality index</th><th _ngcontent-airvisual-web-c35="">Main pollutant</th></tr></thead><tbody _ngcontent-airvisual-web-c35=""><tr _ngcontent-airvisual-web-c35=""><td _ngcontent-airvisual-web-c35="">Unhealthy for Sensitive Groups</td><td _ngcontent-airvisual-web-c35="">112 <span _ngcontent-airvisual-web-c35="">US AQI</span></td><td _ngcontent-airvisual-web-c35="">PM2.5</td></tr></tbody></table>',
#  '<table _ngcontent-airvisual-web-c35="" class="aqi-overview-detail__main-pollution-table" title="What is the current air quality in Karachi?"><thead _ngcontent-airvisual-web-c35=""><tr _ngcontent-airvisual-web-c35=""><th _ngcontent-airvisual-web-c35="">Air pollution level</th><th _ngcontent-airvisual-web-c35="">Air quality index</th><th _ngcontent-airvisual-web-c35="">Main pollutant</th></tr></thead><tbody _ngcontent-airvisual-web-c35=""><tr _ngcontent-airvisual-web-c35=""><td _ngcontent-airvisual-web-c35="">Moderate</td><td _ngcontent-airvisual-web-c35="">91 <span _ngcontent-airvisual-web-c35="">US AQI</span></td><td _ngcontent-airvisual-web-c35="">PM2.5</td></tr></tbody></table>',
#  '<table _ngcontent-airvisual-web-c35="" class="aqi-overview-detail__main-pollution-table" title="What is the current air quality in Incheon?"><thead _ngcontent-airvisual-web-c35=""><tr _ngcontent-airvisual-web-c35=""><th _ngcontent-airvisual-web-c35="">Air pollution level</th><th _ngcontent-airvisual-web-c35="">Air quality index</th><th _ngcontent-airvisual-web-c35="">Main pollutant</th></tr></thead><tbody _ngcontent-airvisual-web-c35=""><tr _ngcontent-airvisual-web-c35=""><td _ngcontent-airvisual-web-c35="">Moderate</td><td _ngcontent-airvisual-web-c35="">94 <span _ngcontent-airvisual-web-c35="">US AQI</span></td><td _ngcontent-airvisual-web-c35="">PM2.5</td></tr></tbody></table>',
#  '<table _ngcontent-airvisual-web-c35="" class="aqi-overview-detail__main-pollution-table" title="What is the current air quality in Kuwait City?"><thead _ngcontent-airvisual-web-c35=""><tr _ngcontent-airvisual-web-c35=""><th _ngcontent-airvisual-web-c35="">Air pollution level</th><th _ngcontent-airvisual-web-c35="">Air quality index</th><th _ngcontent-airvisual-web-c35="">Main pollutant</th></tr></thead><tbody _ngcontent-airvisual-web-c35=""><tr _ngcontent-airvisual-web-c35=""><td _ngcontent-airvisual-web-c35="">Moderate</td><td _ngcontent-airvisual-web-c35="">100 <span _ngcontent-airvisual-web-c35="">US AQI</span></td><td _ngcontent-airvisual-web-c35="">PM2.5</td></tr></tbody></table>',
#  '<table _ngcontent-airvisual-web-c35="" class="aqi-overview-detail__main-pollution-table" title="What is the current air quality in Delhi?"><thead _ngcontent-airvisual-web-c35=""><tr _ngcontent-airvisual-web-c35=""><th _ngcontent-airvisual-web-c35="">Air pollution level</th><th _ngcontent-airvisual-web-c35="">Air quality index</th><th _ngcontent-airvisual-web-c35="">Main pollutant</th></tr></thead><tbody _ngcontent-airvisual-web-c35=""><tr _ngcontent-airvisual-web-c35=""><td _ngcontent-airvisual-web-c35="">Moderate</td><td _ngcontent-airvisual-web-c35="">95 <span _ngcontent-airvisual-web-c35="">US AQI</span></td><td _ngcontent-airvisual-web-c35="">PM2.5</td></tr></tbody></table>']

# %%
# Iterate through all pages

t=[]
c=[]
for x in range(3):      
# HTML object
    html = browser.html
# Parse HTML with Beautiful Soup
    soup = BeautifulSoup(html, 'html.parser')
# Retrieve all elements that contain book information
    results = soup.find_all('div', class_='list_text')  

# Iterate through each book
    for result in results:
        # Use Beautiful Soup's find() method to navigate and retrieve attributes
        title = result.find('div',class_='content_title').text
        if title not in t: 
            t.append(title) 
            content = result.find('div',class_='article_teaser_body').text
            c.append(content)
        #if title not in l: 
        #a.append(title)

        #b.append(content)
            print(f'page:{x}-----------')
            print(f'news_title: {title}')
            print(f'news_p:{content}')       

        # Click the 'Next' button on each page
    try:
        time.sleep(2)
        #browser.find_link_by_text('More').first.click() work
        #browser.click_link_by_partial_text('More') does not work
        browser.click_link_by_text('More')

    except:
        print("Scraping Complete")

browser.quit()

# %%
news_title=t[0]

# %%
news_p=c[0]

# %%
print(f'news_title = {news_title}')
print(f'news_p = {news_p}')

# %%
title = soup.find('div',class_='list_text').find('a').text

title

# %%
content = soup.find('div',class_='article_teaser_body').text
content

# %%
###JPL Mars Space Images - Featured Image

# %%
executable_path = {"executable_path": "/usr/local/bin/chromedriver"}
browser = Browser("chrome", **executable_path, headless=False)

# %%
url_img='https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars'
browser.visit(url_img)

# %%
#find the first div.img which is the current img
html = browser.html
soup = BeautifulSoup(html, 'html.parser')
img_url = soup.find('div',class_='img').find('img')['src']
img_url

# %%
browser.quit()

# %%
#image url
featured_image_url=f'https://www.jpl.nasa.gov{img_url}'
featured_image_url

# %%
###mars_weather---TWITTER

# %%
executable_path = {"executable_path": "/usr/local/bin/chromedriver"}
browser=Browser("chrome", **executable_path, headless=False)

# %%
url_weather='https://twitter.com/marswxreport?lang=en'
#url_weather='https://twitter.com/marswxreport'
browser.visit(url_weather)

# %%
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
mars_weather=soup.find('div',lang='en').find('span').text # class_='css-901oao css-16my406 r-1qd0xha r-ad9z0x r-bcqeeo r-qvutc0'
mars_weather

# %%
browser.quit()

# %%
### Mars Facts---tables

# %%
url_table='https://space-facts.com/mars/'
tables = pd.read_html(url_table)
tables
browser.quit()

# %%
df = tables[0]
df

# %%
df.columns=['parameter','value']
df

# %%
html_table = df.to_html()
html_table

# %%
html_table.replace('\n', '')

# %%
df.to_html('table.html')

# %%
# !open table.html

# %%
#Mars Hemispheres

# %%
executable_path = {"executable_path": "/usr/local/bin/chromedriver"}
browser=Browser("chrome", **executable_path, headless=False)

# %%
url_mars='https://astrogeology.usgs.gov/search/results?q=hemisphere+enhanced&k1=target&v1=Mars'
browser.visit(url_mars)

# %%
html = browser.html
soup = BeautifulSoup(html, 'html.parser')
items=soup.find_all('div', class_='description')
items

# %%
titles_list=[]
url_list = []
hemisphere_image_urls=[]

for item in items:
    title=item.h3.text
    titles_list.append(title)
    url=item.find('a')['href']
    url_list.append(url)
    z={'title':title,'img_url':f'https://astrogeology.usgs.gov{url}'}
    #z=dic(ztitle=title,img_url= url)
    #dic=dict(zip(title, url))
    hemisphere_image_urls.append(z)

# %% [raw]
# hemisphere_image_urls

# %%
image_url=[]
for x in hemisphere_image_urls:
    browser.visit(x['img_url'])
    html = browser.html
    soup = BeautifulSoup(html, 'html.parser')
    x=soup.find('ul').find('a')['href']
    y={'title':title,'img_url':x}
    image_url.append(y)

# %%
browser.quit()

# %%
image_url

# %%
def scrape_info(url):
    executable_path = {"executable_path": "/usr/local/bin/chromedriver"}
    browser = Browser('chrome', **executable_path, headless=False)
    browser.visit(url)
    time.sleep(2)
    html = browser.html
    soup =  BeautifulSoup(html,"html.parser")
    return soup

# %%
mars_data={}

# %%
url_table='https://space-facts.com/mars/'
table_soup = scrape_info(url_table)

# %%
table= table_soup.find('tbody')
str(table)

# %%
table= table_soup.find('tbody').find_all()
table

# %%
mars_data['mars_facts'] = table

# %%
mars_data
